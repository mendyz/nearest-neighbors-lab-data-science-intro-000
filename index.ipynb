# %% [markdown]
# # Nearest Neighbors Lab

# %% [markdown]
# ### Introduction
#
# In this lab, you apply nearest neighbors technique to help a taxi company predict the length of their rides.  Imagine that we are hired to consult for LiftOff, a limo and taxi service that is just opening up in NYC.  Liftoff wants it's taxi drivers to target longer rides, as the longer the ride the more money it makes.  LiftOff has the following theory:
#
# * the pickup location of a taxi ride can help predict the length of the ride.
#
#
#
# LiftOff asks us to do some analysis to write a function that will allow it to **predict the length of a taxi ride for any given location **.
#
# Our technique will be the following:
#   * **Collect** Obtain the data containing all of the taxi information, and only select the attributes of taxi trips that we need
#   * ** Explore ** Examine the attributes of our data, and plot some of our data on a map
#   * ** Train ** Write our nearest neighbors formula, and change the number of nearby trips to predict the length of a new trip
#   * ** Predict ** Use our function to predict trip lengths of new locations

# %% [markdown]
# ### Collect and Explore the data

# %% [markdown]
# #### Collect the Data

# %% [markdown]
# Luckily for us, [NYC Open Data](https://opendata.cityofnewyork.us/) collects information about NYC taxi trips and provides this data on [its website](https://data.cityofnewyork.us/Transportation/2014-Yellow-Taxi-Trip-Data/gn7m-em8n).

# %% [markdown]
# ![](./nyc-taxi.png)

# %% [markdown]
# For your reading pleasure, the data has already been downloaded into the [trips.json](https://github.com/learn-co-curriculum/nearest-neighbors-lab/blob/master/trips.json) file in this lab which you can find here.  We'll use Python's `json` library to take the data from the `trips.json` file and store it as a variable in our notebook.

# %%
import json
# First, read the file
trips_file = open('trips.json')
# Then, convert contents to list of dictionaries 
trips = json.load(trips_file)

# %% [markdown]
# > Press shift + enter

# %% [markdown]
# #### Explore the data

# %% [markdown]
# The next step is to explore the data.  First, let's see how many trips we have.

# %%
len(trips)
trips[0]
# Out:
# {'dropoff_datetime': '2014-11-26T22:31:00.000',
#  'dropoff_latitude': '40.746769999999998',
#  'dropoff_longitude': '-73.997450000000001',
#  'fare_amount': '52',
#  'imp_surcharge': '0',
#  'mta_tax': '0.5',
#  'passenger_count': '1',
#  'payment_type': 'CSH',
#  'pickup_datetime': '2014-11-26T21:59:00.000',
#  'pickup_latitude': '40.64499',
#  'pickup_longitude': '-73.781149999999997',
#  'rate_code': '2',
#  'tip_amount': '0',
#  'tolls_amount': '5.3300000000000001',
#  'total_amount': '57.829999999999998',
#  'trip_distance': '18.379999999999999',
#  'vendor_id': 'VTS'}

# %% [markdown]
# Not bad at all.  Now let's see what each individual trip looks like.  Each trip is a dictionary, so we can see the attributes of each trip with the `keys` function.

# %%
trips[0].keys()
# Out:
# dict_keys(['dropoff_datetime', 'dropoff_latitude', 'dropoff_longitude', 'fare_amount', 'imp_surcharge', 'mta_tax', 'passenger_count', 'payment_type', 'pickup_datetime', 'pickup_latitude', 'pickup_longitude', 'rate_code', 'tip_amount', 'tolls_amount', 'total_amount', 'trip_distance', 'vendor_id'])

# %% [markdown]
# #### Limit our data

# %% [markdown]
# Ok, now that we have explored some of our data, let's begin to think through what data is relevant for our task.

# %% [markdown]
# Remember that our task is to **use the trip location to predict the length of a trip**.  So let's select the `pickup_latitude`, `pickup_longitude`, and `trip_distance` from each trip.  That will give us the trip location and related `trip_distance` for each trip.  Then based on these **actual** trip distances we can use nearest neighbors to predict an **expected** trip distance for a trip, provided an **actual** location.

# %% [markdown]
# ** Add in about trip distance **

# %% [markdown]
# Write a function called `parse_trips(trips)` that returns a list of the trips with only the following attributes:
# * `trip_distance`
# * `pickup_latitude`
# * `pickup_longitude`

# %%
def parse_trips(data):
    def extractFields(item):
        result = {}
        result["trip_distance"] = float(item["trip_distance"])
        result["pickup_latitude"] = item["pickup_latitude"]
        result["pickup_longitude"] = item["pickup_longitude"]
        return result

    #print([extractFields(item) for item in data])
    return [extractFields(item) for item in data]


#data = trips
usefulData = parse_trips(trips)
print(usefulData)

#def parse_trips(trips):
#    parse_trips = []
    #count=0
    #for i in trips:
    #    print(i['trip_distance'])
    #    count+=1
    #    if count == 10:
    #        break
        #if i[distance] > 0:
         #   parse_trips.append(i)
    #results = list(map((lambda item: { "y" : item["y"] }), data))
#    GOOD--->results = list(map((lambda item: { "trip_distance" : item["trip_distance"], "pickup_latitude" : item["pickup_latitude"] }), trips))
    #parse_trips = list(filter(lambda x: x['trip_distance'], trips))
#    return results
# Out:
# [{'trip_distance': 18.38, 'pickup_latitude': '40.64499', 'pickup_longitude': '-73.781149999999997'}, {'trip_distance': 1.3, 'pickup_latitude': '40.766931', 'pickup_longitude': '-73.982097999999993'}, {'trip_distance': 4.5, 'pickup_latitude': '40.777729999999998', 'pickup_longitude': '-73.951902000000004'}, {'trip_distance': 2.4, 'pickup_latitude': '40.795678000000002', 'pickup_longitude': '-73.971048999999994'}, {'trip_distance': 0.84, 'pickup_latitude': '40.762912', 'pickup_longitude': '-73.967782'}, {'trip_distance': 0.8, 'pickup_latitude': '40.731175999999998', 'pickup_longitude': '-73.991572000000005'}, {'trip_distance': 0.5, 'pickup_latitude': '40.800218999999998', 'pickup_longitude': '-73.968097999999998'}, {'trip_distance': 17.3, 'pickup_latitude': '40.648508999999997', 'pickup_longitude': '-73.783507999999998'}, {'trip_distance': 0.63, 'pickup_latitude': '40.721896999999998', 'pickup_longitude': '-73.983492999999996'}, {'trip_distance': 2.8, 'pickup_latitude': '40.791566000000003', 'pickup_longitude': '-73.972223999999997'}, {'trip_distance': 0.6, 'pickup_latitude': '40.744895999999997', 'pickup_longitude': '-73.978618999999995'}, {'trip_distance': 1.1, 'pickup_latitude': '40.721950999999997', 'pickup_longitude': '-73.844435000000004'}, {'trip_distance': 4.2, 'pickup_latitude': '40.732382000000001', 'pickup_longitude': '-74.001682000000002'}, {'trip_distance': 0.4, 'pickup_latitude': '40.768338999999997', 'pickup_longitude': '-73.961478'}, {'trip_distance': 0.6, 'pickup_latitude': '40.775933000000002', 'pickup_longitude': '-73.962446'}, {'trip_distance': 9.8, 'pickup_latitude': '40.794829', 'pickup_longitude': '-73.971475999999996'}, {'trip_distance': 1.05, 'pickup_latitude': '40.758647000000003', 'pickup_longitude': '-73.964877999999999'}, {'trip_distance': 0.74, 'pickup_latitude': '40.713638000000003', 'pickup_longitude': '-74.011587000000006'}, {'trip_distance': 8.4, 'pickup_latitude': '40.774030000000003', 'pickup_longitude': '-73.874596999999994'}, {'trip_distance': 5.1, 'pickup_latitude': '40.728127000000001', 'pickup_longitude': '-73.998869999999997'}, {'trip_distance': 1.4, 'pickup_latitude': '40.759670999999997', 'pickup_longitude': '-73.976687999999996'}, {'trip_distance': 2.7, 'pickup_latitude': '40.772651000000003', 'pickup_longitude': '-73.967095'}, {'trip_distance': 0.8, 'pickup_latitude': '40.770319000000001', 'pickup_longitude': '-73.960222000000002'}, {'trip_distance': 1.12, 'pickup_latitude': '40.720457000000003', 'pickup_longitude': '-73.988065000000006'}, {'trip_distance': 16.0, 'pickup_latitude': '40.754789000000002', 'pickup_longitude': '-73.973606000000004'}, {'trip_distance': 1.4, 'pickup_latitude': '40.755654', 'pickup_longitude': '-73.985845999999995'}, {'trip_distance': 0.9, 'pickup_latitude': '40.741568000000001', 'pickup_longitude': '-73.978341'}, {'trip_distance': 0.74, 'pickup_latitude': '40.736907000000002', 'pickup_longitude': '-73.988619999999997'}, {'trip_distance': 1.5, 'pickup_latitude': '40.76003', 'pickup_longitude': '-73.964842000000004'}, {'trip_distance': 0.7, 'pickup_latitude': '40.721366000000003', 'pickup_longitude': '-74.008286999999996'}, {'trip_distance': 1.97, 'pickup_latitude': '40.760147000000003', 'pickup_longitude': '-73.97627'}, {'trip_distance': 0.96, 'pickup_latitude': '40.745846999999998', 'pickup_longitude': '-74.001817000000003'}, {'trip_distance': 0.74, 'pickup_latitude': '40.753014999999998', 'pickup_longitude': '-73.985247000000001'}, {'trip_distance': 12.7, 'pickup_latitude': '40.644657000000002', 'pickup_longitude': '-73.782229000000001'}, {'trip_distance': 1.17, 'pickup_latitude': '40.738767000000003', 'pickup_longitude': '-74.008600000000001'}, {'trip_distance': 22.8, 'pickup_latitude': '40.773797000000002', 'pickup_longitude': '-73.871065000000002'}, {'trip_distance': 1.5, 'pickup_latitude': '40.743411000000002', 'pickup_longitude': '-73.976860000000002'}, {'trip_distance': 1.5, 'pickup_latitude': '40.758904999999999', 'pickup_longitude': '-73.967896999 ...

# %%
parsed_trips = parse_trips(trips)
parsed_trips and parsed_trips[0]

# {'pickup_latitude': '40.64499',
#  'pickup_longitude': '-73.78115',
#  'trip_distance': '18.38'}
# Out:
# {'trip_distance': 18.38,
#  'pickup_latitude': '40.64499',
#  'pickup_longitude': '-73.781149999999997'}

# %% [markdown]
# Now, there's just one change to make.  If you look at one of the trips, all of the values are strings.  Let's change them to be floats.

# %%
def float_values(data):    
    def extractFields(item):
        result = {}
        result["trip_distance"] = float(item["trip_distance"])
        result["pickup_latitude"] = float(item["pickup_latitude"])
        result["pickup_longitude"] = float(item["pickup_longitude"])
        return result

    #print([extractFields(item) for item in data])
    return [extractFields(item) for item in data]


#data = trips
usefulDataFloat = float_values(parsed_trips)
print(usefulDataFloat)
# Out:
# [{'trip_distance': 18.38, 'pickup_latitude': 40.64499, 'pickup_longitude': -73.78115}, {'trip_distance': 1.3, 'pickup_latitude': 40.766931, 'pickup_longitude': -73.982098}, {'trip_distance': 4.5, 'pickup_latitude': 40.77773, 'pickup_longitude': -73.951902}, {'trip_distance': 2.4, 'pickup_latitude': 40.795678, 'pickup_longitude': -73.971049}, {'trip_distance': 0.84, 'pickup_latitude': 40.762912, 'pickup_longitude': -73.967782}, {'trip_distance': 0.8, 'pickup_latitude': 40.731176, 'pickup_longitude': -73.991572}, {'trip_distance': 0.5, 'pickup_latitude': 40.800219, 'pickup_longitude': -73.968098}, {'trip_distance': 17.3, 'pickup_latitude': 40.648509, 'pickup_longitude': -73.783508}, {'trip_distance': 0.63, 'pickup_latitude': 40.721897, 'pickup_longitude': -73.983493}, {'trip_distance': 2.8, 'pickup_latitude': 40.791566, 'pickup_longitude': -73.972224}, {'trip_distance': 0.6, 'pickup_latitude': 40.744896, 'pickup_longitude': -73.978619}, {'trip_distance': 1.1, 'pickup_latitude': 40.721951, 'pickup_longitude': -73.844435}, {'trip_distance': 4.2, 'pickup_latitude': 40.732382, 'pickup_longitude': -74.001682}, {'trip_distance': 0.4, 'pickup_latitude': 40.768339, 'pickup_longitude': -73.961478}, {'trip_distance': 0.6, 'pickup_latitude': 40.775933, 'pickup_longitude': -73.962446}, {'trip_distance': 9.8, 'pickup_latitude': 40.794829, 'pickup_longitude': -73.971476}, {'trip_distance': 1.05, 'pickup_latitude': 40.758647, 'pickup_longitude': -73.964878}, {'trip_distance': 0.74, 'pickup_latitude': 40.713638, 'pickup_longitude': -74.011587}, {'trip_distance': 8.4, 'pickup_latitude': 40.77403, 'pickup_longitude': -73.874597}, {'trip_distance': 5.1, 'pickup_latitude': 40.728127, 'pickup_longitude': -73.99887}, {'trip_distance': 1.4, 'pickup_latitude': 40.759671, 'pickup_longitude': -73.976688}, {'trip_distance': 2.7, 'pickup_latitude': 40.772651, 'pickup_longitude': -73.967095}, {'trip_distance': 0.8, 'pickup_latitude': 40.770319, 'pickup_longitude': -73.960222}, {'trip_distance': 1.12, 'pickup_latitude': 40.720457, 'pickup_longitude': -73.988065}, {'trip_distance': 16.0, 'pickup_latitude': 40.754789, 'pickup_longitude': -73.973606}, {'trip_distance': 1.4, 'pickup_latitude': 40.755654, 'pickup_longitude': -73.985846}, {'trip_distance': 0.9, 'pickup_latitude': 40.741568, 'pickup_longitude': -73.978341}, {'trip_distance': 0.74, 'pickup_latitude': 40.736907, 'pickup_longitude': -73.98862}, {'trip_distance': 1.5, 'pickup_latitude': 40.76003, 'pickup_longitude': -73.964842}, {'trip_distance': 0.7, 'pickup_latitude': 40.721366, 'pickup_longitude': -74.008287}, {'trip_distance': 1.97, 'pickup_latitude': 40.760147, 'pickup_longitude': -73.97627}, {'trip_distance': 0.96, 'pickup_latitude': 40.745847, 'pickup_longitude': -74.001817}, {'trip_distance': 0.74, 'pickup_latitude': 40.753015, 'pickup_longitude': -73.985247}, {'trip_distance': 12.7, 'pickup_latitude': 40.644657, 'pickup_longitude': -73.782229}, {'trip_distance': 1.17, 'pickup_latitude': 40.738767, 'pickup_longitude': -74.0086}, {'trip_distance': 22.8, 'pickup_latitude': 40.773797, 'pickup_longitude': -73.871065}, {'trip_distance': 1.5, 'pickup_latitude': 40.743411, 'pickup_longitude': -73.97686}, {'trip_distance': 1.5, 'pickup_latitude': 40.758905, 'pickup_longitude': -73.967897}, {'trip_distance': 1.7, 'pickup_latitude': 40.733877, 'pickup_longitude': -73.989602}, {'trip_distance': 0.95, 'pickup_latitude': 40.726162, 'pickup_longitude': -73.983432}, {'trip_distance': 5.88, 'pickup_latitude': 40.775122, 'pickup_longitude': -73.947765}, {'trip_distance': 4.1, 'pickup_latitude': 40.75987, 'pickup_longitude': -73.978487}, {'trip_distance': 1.09, 'pickup_latitude': 40.707087, 'pickup_longitude': -73.94328}, {'trip_distance': 1.39, 'pickup_latitude': 40.741912, 'pickup_longitude': -74.003578}, {'trip_distance': 11.2, 'pickup_latitude': 40.769112, 'pickup_longitude': -73.862679}, {'trip_distance': 2.56, 'pickup_latitude': 40.785807, 'pickup_longitude': -73.976387}, {'trip_distance': 1.03, 'pickup_la ...

# %%
cleaned_trips = float_values(parsed_trips)
print(cleaned_trips)
# Out:
# [{'trip_distance': 18.38, 'pickup_latitude': 40.64499, 'pickup_longitude': -73.78115}, {'trip_distance': 1.3, 'pickup_latitude': 40.766931, 'pickup_longitude': -73.982098}, {'trip_distance': 4.5, 'pickup_latitude': 40.77773, 'pickup_longitude': -73.951902}, {'trip_distance': 2.4, 'pickup_latitude': 40.795678, 'pickup_longitude': -73.971049}, {'trip_distance': 0.84, 'pickup_latitude': 40.762912, 'pickup_longitude': -73.967782}, {'trip_distance': 0.8, 'pickup_latitude': 40.731176, 'pickup_longitude': -73.991572}, {'trip_distance': 0.5, 'pickup_latitude': 40.800219, 'pickup_longitude': -73.968098}, {'trip_distance': 17.3, 'pickup_latitude': 40.648509, 'pickup_longitude': -73.783508}, {'trip_distance': 0.63, 'pickup_latitude': 40.721897, 'pickup_longitude': -73.983493}, {'trip_distance': 2.8, 'pickup_latitude': 40.791566, 'pickup_longitude': -73.972224}, {'trip_distance': 0.6, 'pickup_latitude': 40.744896, 'pickup_longitude': -73.978619}, {'trip_distance': 1.1, 'pickup_latitude': 40.721951, 'pickup_longitude': -73.844435}, {'trip_distance': 4.2, 'pickup_latitude': 40.732382, 'pickup_longitude': -74.001682}, {'trip_distance': 0.4, 'pickup_latitude': 40.768339, 'pickup_longitude': -73.961478}, {'trip_distance': 0.6, 'pickup_latitude': 40.775933, 'pickup_longitude': -73.962446}, {'trip_distance': 9.8, 'pickup_latitude': 40.794829, 'pickup_longitude': -73.971476}, {'trip_distance': 1.05, 'pickup_latitude': 40.758647, 'pickup_longitude': -73.964878}, {'trip_distance': 0.74, 'pickup_latitude': 40.713638, 'pickup_longitude': -74.011587}, {'trip_distance': 8.4, 'pickup_latitude': 40.77403, 'pickup_longitude': -73.874597}, {'trip_distance': 5.1, 'pickup_latitude': 40.728127, 'pickup_longitude': -73.99887}, {'trip_distance': 1.4, 'pickup_latitude': 40.759671, 'pickup_longitude': -73.976688}, {'trip_distance': 2.7, 'pickup_latitude': 40.772651, 'pickup_longitude': -73.967095}, {'trip_distance': 0.8, 'pickup_latitude': 40.770319, 'pickup_longitude': -73.960222}, {'trip_distance': 1.12, 'pickup_latitude': 40.720457, 'pickup_longitude': -73.988065}, {'trip_distance': 16.0, 'pickup_latitude': 40.754789, 'pickup_longitude': -73.973606}, {'trip_distance': 1.4, 'pickup_latitude': 40.755654, 'pickup_longitude': -73.985846}, {'trip_distance': 0.9, 'pickup_latitude': 40.741568, 'pickup_longitude': -73.978341}, {'trip_distance': 0.74, 'pickup_latitude': 40.736907, 'pickup_longitude': -73.98862}, {'trip_distance': 1.5, 'pickup_latitude': 40.76003, 'pickup_longitude': -73.964842}, {'trip_distance': 0.7, 'pickup_latitude': 40.721366, 'pickup_longitude': -74.008287}, {'trip_distance': 1.97, 'pickup_latitude': 40.760147, 'pickup_longitude': -73.97627}, {'trip_distance': 0.96, 'pickup_latitude': 40.745847, 'pickup_longitude': -74.001817}, {'trip_distance': 0.74, 'pickup_latitude': 40.753015, 'pickup_longitude': -73.985247}, {'trip_distance': 12.7, 'pickup_latitude': 40.644657, 'pickup_longitude': -73.782229}, {'trip_distance': 1.17, 'pickup_latitude': 40.738767, 'pickup_longitude': -74.0086}, {'trip_distance': 22.8, 'pickup_latitude': 40.773797, 'pickup_longitude': -73.871065}, {'trip_distance': 1.5, 'pickup_latitude': 40.743411, 'pickup_longitude': -73.97686}, {'trip_distance': 1.5, 'pickup_latitude': 40.758905, 'pickup_longitude': -73.967897}, {'trip_distance': 1.7, 'pickup_latitude': 40.733877, 'pickup_longitude': -73.989602}, {'trip_distance': 0.95, 'pickup_latitude': 40.726162, 'pickup_longitude': -73.983432}, {'trip_distance': 5.88, 'pickup_latitude': 40.775122, 'pickup_longitude': -73.947765}, {'trip_distance': 4.1, 'pickup_latitude': 40.75987, 'pickup_longitude': -73.978487}, {'trip_distance': 1.09, 'pickup_latitude': 40.707087, 'pickup_longitude': -73.94328}, {'trip_distance': 1.39, 'pickup_latitude': 40.741912, 'pickup_longitude': -74.003578}, {'trip_distance': 11.2, 'pickup_latitude': 40.769112, 'pickup_longitude': -73.862679}, {'trip_distance': 2.56, 'pickup_latitude': 40.785807, 'pickup_longitude': -73.976387}, {'trip_distance': 1.03, 'pickup_la ...

# %%
cleaned_trips[0]

# {'pickup_latitude': 40.64499,
#  'pickup_longitude': -73.78115,
#  'trip_distance': 18.38}
# Out:
# {'trip_distance': 18.38,
#  'pickup_latitude': 40.64499,
#  'pickup_longitude': -73.78115}

# %% [markdown]
# ### Exploring the Data

# %% [markdown]
# Now that we have paired down our data, let's get a sense of our trip data.  We can use the `folium` Python library to plot a map of Manhattan, and our data.  First we must import `folium`, and then use the `Map` function to pass through a `location`, and `zoom_start`.  If a map isn't showing up below, copy and paste the command `pip install -r requirements.txt` into your terminal to install `folium` then try again.

# %%
import folium
manhattan_map = folium.Map(location=[40.7589, -73.9851], zoom_start=11)

# %%
type(manhattan_map)
# Out:
# folium.folium.Map

# %%
manhattan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Ok, now let's see how we could add a dot to mark a specific location.  We'll start with Times Square.

# %%
marker = folium.CircleMarker(location = [40.7589, -73.9851], radius=10)
marker.add_to(manhattan_map)
type(marker)
# Out:
# folium.vector_layers.CircleMarker

# %% [markdown]
# Above, we first create a marker.  Then we add that circle marker to the `manhattan_map` we created earlier.

# %%
manhattan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Do you see that blue dot near Time's Square?  That is our marker.
#
# So now that we can plot one marker on a map, we should have a sense of how we can plot many markers on a map to display our taxi ride data.  We simply plot a map, and then we add a marker for each location of a taxi trip.
#
# Now let's write some functions to allow us to plot maps and add markers a little more easily.

# %% [markdown]
# #### Writing some map plotting functions

# %% [markdown]
# As a first step towards this, note that the functions to create both a marker and map each take in a location as two element list, representing the latitude and longitude values.  Take another look:
#
# ```python
# marker = folium.CircleMarker(location = [40.7589, -73.9851])
# manhattan_map = folium.Map(location=[40.7589, -73.9851])
# ```
#
# So let's write a function to create the two element list from a trip.  Write a function called `location` that  takes in a trip as an argument and returns a list where the first element is the latitude and the second is the longitude.  Remember that a location looks like the following:

# %%
first_trip = {'pickup_latitude': 40.64499, 'pickup_longitude': -73.78115,  'trip_distance': 18.38}
first_trip
# Out:
# {'pickup_latitude': 40.64499,
#  'pickup_longitude': -73.78115,
#  'trip_distance': 18.38}

# %%
def location(trip):
    #print(trip)
    #return a list where the first element is the lat and the second is the long
    location_list = []
    #print(trip['pickup_latitude'])
    location_list.append(trip['pickup_latitude'])
    location_list.append(trip['pickup_longitude'])
    #print(location_list)
    return location_list
    #print(location_list)
location(first_trip)
# Out:
# [40.64499, -73.78115]

# %%
first_location = location(first_trip) # [40.64499, -73.78115]
first_location # [40.64499, -73.78115]
# Out:
# [40.64499, -73.78115]

# %% [markdown]
# Ok, now that we can turn a trip into a location, let's turn a location into a marker.  Write a function called `to_marker` that takes in a location (in the form of a list) as an argument, and returns a folium `circleMarker` for that location.  The radius of the marker should always equal 6.

# %%
def to_marker(location):
    circleMarker = folium.CircleMarker(location = location, radius=6)
    print(circleMarker)
    return circleMarker

#marker = folium.CircleMarker(location = location, radius=10)
#marker = folium.CircleMarker(location = [40.7589, -73.9851])
times_square_marker = to_marker([40.7589, -73.9851])
print(times_square_marker)
# Out:
# <folium.vector_layers.CircleMarker object at 0x7fdbd47eacf8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47eacf8>

# %%
import json
times_square_marker = to_marker([40.7589, -73.9851])

times_square_marker and times_square_marker.location # [40.7589, -73.9851]
times_square_marker and json.loads(times_square_marker.options)['radius'] # 6
# Out:
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ea860>
# 6

# %% [markdown]
# Ok, now that we know how to produce a single marker, let's write a function to produce lots.  We can write a function called `markers_from_trips` that takes in a list of trips, and returns a marker object for each trip.

# %%
location(cleaned_trips[0])
# Out:
# [40.64499, -73.78115]

# %%
def markers_from_trips(trips):
    trip_markers = []
    for trip in trips:
        marker = to_marker(location(trip))
        trip_markers.append(marker)
    #len(trip_markers)
    return trip_markers

# %%
trip_markers = markers_from_trips(cleaned_trips)
# Out:
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ead30>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ea9b0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ea668>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ea550>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47eabe0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47eaef0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47eacf8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47eafd0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ea2b0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ea400>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ead68>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ea7b8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47eaf60>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ea3c8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47eacc0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ea630>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47eae80>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ea240>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4fbb1d0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4828dd8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ea4a8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ea048>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ea898>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2208>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2198>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ea208>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47eaa20>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47eae48>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ea278>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ea6a0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ea438>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ea128>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ea710>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47eac88>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ea470>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47eae10>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2080>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e21d0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e20f0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e26a0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e26d8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e28d0>
# <folium.vector_layers.CircleMarker object at 0x7fdc0b4f0b00>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ea320>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47eac18>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47eab38>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47eadd8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47eab70>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ea390>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ea2e8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2320>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e22e8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2128>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e25f8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e27b8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2710>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e29b0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2ac8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2400>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2550>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2588>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2b70>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2518>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2c50>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ea0f0>
# <folium.vector_layers.CircleMarker object at 0x7fdc0aeb85f8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47eada0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47eaa58>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ea780>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2438>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2b00>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e23c8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2978>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2a58>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2358>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2390>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2048>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2cf8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2be0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2e10>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2e48>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2ef0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2f98>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2f28>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b080>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b160>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2c18>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2d68>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2240>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2a90>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e29e8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e20b8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2630>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2908>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e24e0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e25c0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47eaf28>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ea8d0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ea7f0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b208>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b0f0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b390>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b3c8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b470>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b518>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b5c0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b668>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47eaf98>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ea5f8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2668>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2780>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2d30>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2160>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2dd8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2f60>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2eb8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b588>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b438>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b048>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b2e8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b710>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b5f8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b828>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b860>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b908>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b9b0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472ba58>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472bb00>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472bba8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ea160>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ea358>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2860>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2470>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2278>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2cc0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e24a8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47d23c8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47d2588>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47d2320>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47d26d8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b9e8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472ba20>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b8d0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b0b8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b748>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b198>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b240>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b630>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472bc50>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472bb38>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47d2d30>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47d2a58>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e27f0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ea4e0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2a20>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2e80>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2c88>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b320>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b4e0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b1d0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b898>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b978>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b6d8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472bbe0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472bdd8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b940>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472beb8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472bf60>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472bef0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742048>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47420f0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47421d0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472bf98>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472be10>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472bcf8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b6a0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b7f0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b358>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47eab00>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b7b8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b780>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2ba8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47d2978>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47d2898>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2898>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742080>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742160>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742400>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742438>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47424e0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742588>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742630>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47426d8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742780>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47d2400>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47ea080>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2da0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b278>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472bac8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b128>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472bcc0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472be48>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47425c0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47425f8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47424a8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47420b8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742358>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742828>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742710>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742940>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742978>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742a20>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742ac8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742b70>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742c18>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742cc0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b550>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47d21d0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472bd68>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472bc88>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2940>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742b00>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742b38>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47429e8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742128>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742860>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742208>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47422b0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47426a0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742d68>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742c50>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742e80>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742eb8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742f60>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2b38>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b400>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472be80>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b4a8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742518>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742da0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47422e8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742470>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47427b8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742198>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742be0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742ef0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742c88>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d048>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d128>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d240>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d2e8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d390>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d438>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d4e0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d588>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d630>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d6d8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d780>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742e10>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742d30>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742320>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742ba8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742e48>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742898>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2828>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472bda0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472bfd0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d470>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d320>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d400>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d0f0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d1d0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d668>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d860>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d908>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d160>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d9e8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475da90>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475db38>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475dbe0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475dc88>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e2fd0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472bb70>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742390>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742a90>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742a58>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742908>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d978>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d710>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d7b8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d2b0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d080>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d5f8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d278>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d518>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475db70>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475dd68>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475de10>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d748>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475def0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475df98>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475df28>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47e22b0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472b2b0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742f98>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47428d0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475dc18>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d5c0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475dda0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d4a8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d6a0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d9b0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d8d0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475da58>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475dac8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d940>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f20b8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f21d0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2278>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2320>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f23c8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2470>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2518>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f25c0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475de80>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d0b8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d208>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472bf28>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d550>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475de48>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475dcc0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742550>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47429b0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f24e0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2390>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2080>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2160>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2668>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2550>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2780>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f27b8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2860>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2908>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f29b0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2a58>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2b00>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742748>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475dc50>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d828>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475db00>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475dba8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475df60>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2a20>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2710>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f20f0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2240>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f24a8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2358>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2438>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2ba8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2a90>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2cc0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2cf8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2da0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2e48>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2ef0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2f98>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2f28>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2e80>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2e10>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2400>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f22e8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f29e8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2048>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2128>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f27f0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f25f8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f26d8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742f28>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d3c8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d198>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475dd30>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47070b8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47071d0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707278>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707320>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47073c8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707470>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707518>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47075c0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475ddd8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475dfd0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47d22b0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47427f0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742668>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47423c8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2198>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2be0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2208>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2d68>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2b38>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2940>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2630>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2fd0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707588>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707438>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47070f0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707240>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707080>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47076a0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707748>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707198>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2c88>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2828>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2898>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472bd30>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47d2860>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2978>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742fd0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742dd8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d898>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475da20>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47072e8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707358>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707390>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47074a8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707898>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47078d0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47077b8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47079b0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707a58>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707b00>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707ba8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707c50>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742240>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475dcf8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2588>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2f60>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2b70>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f22b0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707a90>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707ac8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707978>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47072b0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707828>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707710>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707208>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47077f0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707d68>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707da0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707c88>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707e80>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707f28>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707fd0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707eb8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2d30>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742278>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2dd8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2748>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707dd8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707b38>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707be0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47076d8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707128>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707908>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475deb8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707940>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707cc0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707550>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717048>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717128>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717240>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47172e8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717390>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717438>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47174e0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717588>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d358>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707b70>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707400>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707780>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4742cf8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47074e0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707ef0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707160>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2ac8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2c18>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717278>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47170f0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47171d0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717630>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717518>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717748>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717780>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717828>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47178d0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717978>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717a20>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717ac8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f28d0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707f60>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707e48>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707c18>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707860>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707630>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47179e8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717898>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47176a0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717710>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717400>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717208>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717320>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717b70>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717a58>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717c88>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717cc0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717d68>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717e10>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717eb8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717f60>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717ef0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707f98>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2eb8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47075f8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707d30>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717cf8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717c18>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717550>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717358>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47179b0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717160>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717668>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717860>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717940>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47177f0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4048>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4160>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4240>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b42e8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4390>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4438>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b44e0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4588>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717fd0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47175c0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47173c8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717080>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f26a0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717198>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717e80>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717be0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707a20>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b43c8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4400>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b42b0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b40f0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4630>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4518>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4748>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4780>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4828>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b48d0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4978>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4a20>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4ac8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707e10>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717e48>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717dd8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717d30>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47174a8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717ba8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b49e8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4898>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b46a0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4710>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4198>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b41d0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b44a8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4b70>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4a58>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4c88>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4cc0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4d68>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4e48>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4f28>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4f98>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717f28>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707048>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717da0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717c50>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4e10>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4ef0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4d30>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4550>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4ba8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4208>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4278>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b47b8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b47f0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4a90>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b45c0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d048>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d128>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d240>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d2e8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d3c8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d4a8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d4e0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707cf8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b46d8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4470>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b40b8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4dd8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4320>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4fd0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4b00>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717b00>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47177b8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d160>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d400>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d1d0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d080>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d438>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d668>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d6d8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d710>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d7b8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d860>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d908>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d9b0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47172b0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4e80>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4eb8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4707668>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4128>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4c18>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4da0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d8d0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d780>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d550>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d5f8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d278>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d0b8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472da58>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d940>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472db70>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472dba8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472dc50>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472dcf8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472dda0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472de48>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472def0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4be0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46f2c50>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47079e8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b45f8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4668>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717908>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717a90>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472dd30>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472dd68>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472dc18>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d470>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472da90>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d6a0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d588>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d748>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d828>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472da20>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472df98>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d7f0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472de80>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce080>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce160>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472df28>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472dfd0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d358>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472db38>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d390>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472dbe0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472dcc0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d208>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717b38>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717f98>
# <folium.vector_layers.CircleMarker object at 0x7fdbd475d7f0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4f60>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b49b0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4b38>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce278>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce320>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce198>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce400>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce4a8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce550>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce5f8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce6a0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4080>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47176d8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4940>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4860>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472deb8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d0f0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d198>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472df60>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d518>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce4e0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce518>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce3c8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce0f0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce748>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce630>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce860>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce898>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce940>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce9e8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46cea90>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ceb38>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46cebe0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472de10>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47175f8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4358>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d5c0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4717470>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d320>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46cea20>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce9b0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce7b8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce828>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce358>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce390>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce5c0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46cec88>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ceb70>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ceda0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46cedd8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46cee80>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46cef28>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46cefd0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ceeb8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e30f0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce8d0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46cee48>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ced68>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce0b8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce470>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce7f0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4908>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47170b8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce6d8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ceb00>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce128>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d630>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472dc88>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3080>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3240>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3320>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3358>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3400>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e34a8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3550>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e35f8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e36a0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4cf8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d2b0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46cee10>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce908>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce2e8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce048>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce668>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46cec18>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce438>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3390>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e30b8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3128>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3208>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3748>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3630>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3860>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3898>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3940>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e39e8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3a90>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3b38>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3be0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46b4c50>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46cef98>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46cea58>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ceba8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472db00>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472ddd8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e38d0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e37f0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e31d0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e32e8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3588>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e35c0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3160>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3710>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3cf8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3d30>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3c18>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3e10>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3eb8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3f60>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3ef0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472dac8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3ba8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3f28>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3ac8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3b70>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3518>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3470>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3908>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3828>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e39b0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3a20>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e36d8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ceef0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46cecc0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce978>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b0b8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b1d0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b278>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b320>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b3c8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b470>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b518>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ced30>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce780>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3dd8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e37b8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3278>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3780>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d9e8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3cc0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3668>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3e80>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b438>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b2e8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b160>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b5c0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b4a8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b6d8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b710>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b7b8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b860>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b908>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b9b0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467ba58>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3d68>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e34e0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3f98>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3978>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3a58>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce2b0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b898>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b8d0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b780>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b128>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b5f8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b2b0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b390>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467bb00>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b9e8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467bc18>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467bc50>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467bcf8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467bda0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467be48>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467bef0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467bf98>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46cecf8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3c88>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3e48>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e33c8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467beb8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467bd68>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467bb70>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467bbe0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b208>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b0f0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b550>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b198>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b978>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467bf28>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467ba20>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691080>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691160>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691278>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691320>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46913c8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691470>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691518>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467bdd8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b940>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b358>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467bb38>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467bd30>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467be10>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467bcc0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3b00>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3048>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3fd0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691198>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691208>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46910b8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46915c0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46914a8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46916d8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691710>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46917b8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691860>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691908>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46919b0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691a58>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467bc88>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b4e0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b7f0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467be80>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d898>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3438>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e32b0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b668>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46cec50>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce1d0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46cef60>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691978>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691828>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691630>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46916a0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691390>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691128>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46912b0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691ac8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691b38>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691be0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46914e0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47c3fd0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47af0b8>
# <folium.vector_layers.CircleMarker object at 0x7fdc080cdfd0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3da0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472d978>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4fb3cf8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce710>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce240>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b240>
# <folium.vector_layers.CircleMarker object at 0x7fdbd472ba90>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b748>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467bf60>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b6a0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691ba8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46911d0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691668>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691048>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b400>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3c50>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ceac8>
# <folium.vector_layers.CircleMarker object at 0x7fdc08438320>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47afeb8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4fb3e48>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4fb3ef0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b630>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691438>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691a90>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691a20>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691940>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46917f0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691cf8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691da0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691898>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691e80>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691f28>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691fd0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691eb8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691400>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691f98>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691c50>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46918d0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691cc0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd47af080>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46ce208>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691588>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4fb3da0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46910f0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b048>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467bfd0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467b588>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46a0198>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46a0080>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46a02e8>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46a0390>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46a0438>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46a04e0>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46a0588>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46a0630>
# <folium.vector_layers.CircleMarker object at 0x7fdbd46e3198>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4fbb128>
# <folium.vector_layers.CircleMarker object at 0x7fdbd467ba90>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691d68>
# <folium.vector_layers.CircleMarker object at 0x7fdbd4691b00>

# %%
cleaned_trips[0:4]
# Out:
# [{'trip_distance': 18.38,
#   'pickup_latitude': 40.64499,
#   'pickup_longitude': -73.78115},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.766931,
#   'pickup_longitude': -73.982098},
#  {'trip_distance': 4.5,
#   'pickup_latitude': 40.77773,
#   'pickup_longitude': -73.951902},
#  {'trip_distance': 2.4,
#   'pickup_latitude': 40.795678,
#   'pickup_longitude': -73.971049}]

# %%
len(trip_markers)
# Out:
# 1000

# %%
trip_markers and len(trip_markers) # 1000

list(map(lambda marker: marker.location, trip_markers[0:4]))
# [[40.64499, -73.78115],
#  [40.766931, -73.982098],
#  [40.77773, -73.951902],
#  [40.795678, -73.971049]]
# Out:
# [[40.64499, -73.78115],
#  [40.766931, -73.982098],
#  [40.77773, -73.951902],
#  [40.795678, -73.971049]]

# %% [markdown]
# Ok, now that we have a function that creates locations, and a function that creates markers, it is time to write a function to plot a map.
#
# Write a function called `map_from` that, provided the first argument of a list location and second argument an integer representing the `zoom_start`, returns a `folium` map the corresponding location and `zoom_start` attributes.
#
# > Hint: The following is how to write a map with folium:
# > ```python
#     folium.Map(location=location, zoom_start=zoom_amount)
# > ```

# %%
def map_from(location, zoom_amount):
    folium_map = folium.Map(location=location, zoom_start=zoom_amount)
    return folium_map 

#folium.Map(location=location, zoom_start=zoom_amount)

# %%
times_square_map = map_from([40.7589, -73.9851], 15)
print(times_square_map)
times_square_map and times_square_map.location # [40.7589, -73.9851]
print(times_square_map and times_square_map.location)
times_square_map and times_square_map.zoom_start # 15
# Out:
# <folium.folium.Map object at 0x7fdbd46a0d68>
# [40.7589, -73.9851]
# 15

# %%
times_square_marker and times_square_marker.add_to(times_square_map)
times_square_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now that we have a marker and a map, now let's write a function that adds a lot of markers to a map.  This function should add each marker in the list to the map object then return the updated map object.

# %%
manhattan_map = map_from([40.7589, -73.9851], 13)
manhattan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# This function should add each marker in the list to the map object then return the updated map object.

def add_markers(markers, map_obj):
    for i in markers:
        i.add_to(map_obj)
    return map_obj
#marker = folium.CircleMarker(location = [40.7589, -73.9851], radius=10)
#marker.add_to(manhattan_map)


#    def test_add_markers(self):
#        cleaned_trips = [{'pickup_latitude': 40.64499, 'pickup_longitude': -73.78115, 'trip_distance': 18.38},
#        {'pickup_latitude': 40.766931, 'pickup_longitude': -73.982098, 'trip_distance': 1.3},
#        {'pickup_latitude': 40.77773, 'pickup_longitude': -73.951902, 'trip_distance': 4.5},
#        {'pickup_latitude': 40.795678, 'pickup_longitude': -73.971049, 'trip_distance': 2.4}]
#        markers = markers_from_trips(cleaned_trips)
#        manhattan_map = map_from([40.7589, -73.9851], 13)
#        self.assertEqual(add_markers(markers, manhattan_map), manhattan_map)

# %%
type(trip_markers)
#print(trip_markers)
#print(manhattan_map)
# Out:
# list

# %%
map_with_markers = add_markers(trip_markers, manhattan_map)
type(map_with_markers)
# Out:
# folium.folium.Map

# %%
map_with_markers
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Using Nearest Neighbors

# %% [markdown]
# Ok, let's write a function that given a latitude and longitude will predict the distance for us.  We'll do this by first finding the nearest trips given a latitude and longitude.

# %% [markdown]
# Here we once again apply the nearest neighbors formula. As a first step, write a function named `distance_location` that calculates the distance in pickup location between two trips.

# %%
import math

def distance_location(selected_trip, neighbor_trip):
   # print(neighbor_trip['pickup_latitude'])
    #print(selected_trip['pickup_latitude'])
    #print(neighbor_trip['pickup_longitude'])
    #print(selected_trip['pickup_longitude'])
    distance_location = (neighbor_trip['pickup_latitude']  - selected_trip['pickup_latitude'])**2 + (neighbor_trip['pickup_longitude'] - selected_trip['pickup_longitude'])**2
    return math.sqrt(distance_location)
                                  
#distance_squared = (neighbor['x'] - selected_individual['x'])**2 + (neighbor['y'] - selected_individual['y'])**2
#   return math.sqrt(distance_squared)


#side_c = sqrt(side_a * side_a + side_b * side_b)

# %%
first_trip = {'pickup_latitude': 40.64499, 'pickup_longitude': -73.78115, 'trip_distance': 18.38}
second_trip = {'pickup_latitude': 40.766931, 'pickup_longitude': -73.982098, 'trip_distance': 1.3}
distance_first_and_second = distance_location(first_trip, second_trip)

distance_first_and_second and round(distance_first_and_second, 3) # 0.235
# Out:
# 0.235

# %% [markdown]
# Ok, next write a function called `distance_between_neighbors` that adds a new key-value pair, called `distance_from_selected`, that calculates the distance of the `neighbor_trip` from the `selected_trip`.

# %%
def distance_between_neighbors(selected_trip, neighbor_trip):
    #use the distance_location function and just add the value to the dict as a new dict
    #print(selected_trip)
    #print(neighbor_trip)
    #selected_trip['distance_from_selected']= distance_location(selected_trip, neighbor_trip)
    neighbor_trip['distance_from_selected']= distance_location(selected_trip, neighbor_trip)
    return neighbor_trip
#    d['mynewkey'] = 'mynewvalue'
# default_data['item3'] = 3

# %%
distance_between_neighbors(first_trip, second_trip)

# {'distance_from_selected': 0.23505256047318146,
#  'pickup_latitude': 40.766931,
#  'pickup_longitude': -73.982098,
#  'trip_distance': 1.3}
# Out:
# {'pickup_latitude': 40.766931,
#  'pickup_longitude': -73.982098,
#  'trip_distance': 0.23505256047318146,
#  'distance_from_selected': 0.23505256047318146}

# %% [markdown]
# Ok, now our `neighbor_trip` has another attribute called `distance_from_selected`, that indicates the distance from the `neighbor_trip`'s pickup location from the `selected_trip`.

# %% [markdown]
# > ** Understand the data:** Our dictionary now has a few attributes, two of which say distance.  Let's make sure we understand the difference.
# > * **`distance_from_selected`:** This is our calculation of the distance of the neighbor's pickup location from the selected trip.
# > * **`trip_distance`:** This is the attribute we were provided initially.  It tells us the length of the neighbor's taxi trip from pickup to drop-off.

# %% [markdown]
# Next, write a function called `distance_all` that provided a list of neighbors, returns each of those neighbors with their respective `distance_from_selected` numbers.

# %%
def distance_all(first_trip, clean_trips):
    distance_all = []
    for trips in cleaned_trips:
        #print(trips)
        distance_all.append(distance_between_neighbors(first_trip, trips))
    return distance_all

# %%
cleaned_trips and distance_all(first_trip, cleaned_trips[0:4])
# Out:
# [{'trip_distance': 18.38,
#   'pickup_latitude': 40.64499,
#   'pickup_longitude': -73.78115,
#   'distance_from_selected': 0.0},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.766931,
#   'pickup_longitude': -73.982098,
#   'distance_from_selected': 0.23505256047318146},
#  {'trip_distance': 4.5,
#   'pickup_latitude': 40.77773,
#   'pickup_longitude': -73.951902,
#   'distance_from_selected': 0.2162779533470808},
#  {'trip_distance': 2.4,
#   'pickup_latitude': 40.795678,
#   'pickup_longitude': -73.971049,
#   'distance_from_selected': 0.24242215976473674},
#  {'trip_distance': 0.84,
#   'pickup_latitude': 40.762912,
#   'pickup_longitude': -73.967782,
#   'distance_from_selected': 0.22076481039332593},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.731176,
#   'pickup_longitude': -73.991572,
#   'distance_from_selected': 0.22738831254047148},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.800219,
#   'pickup_longitude': -73.968098,
#   'distance_from_selected': 0.2429929981398639},
#  {'trip_distance': 17.3,
#   'pickup_latitude': 40.648509,
#   'pickup_longitude': -73.783508,
#   'distance_from_selected': 0.0042359798158141185},
#  {'trip_distance': 0.63,
#   'pickup_latitude': 40.721897,
#   'pickup_longitude': -73.983493,
#   'distance_from_selected': 0.21646564692347695},
#  {'trip_distance': 2.8,
#   'pickup_latitude': 40.791566,
#   'pickup_longitude': -73.972224,
#   'distance_from_selected': 0.24081901347692852},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.744896,
#   'pickup_longitude': -73.978619,
#   'distance_from_selected': 0.2213034450635568},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.721951,
#   'pickup_longitude': -73.844435,
#   'distance_from_selected': 0.09963928314676157},
#  {'trip_distance': 4.2,
#   'pickup_latitude': 40.732382,
#   'pickup_longitude': -74.001682,
#   'distance_from_selected': 0.23721661975503053},
#  {'trip_distance': 0.4,
#   'pickup_latitude': 40.768339,
#   'pickup_longitude': -73.961478,
#   'distance_from_selected': 0.21847920584119773},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.775933,
#   'pickup_longitude': -73.962446,
#   'distance_from_selected': 0.2236387910560279},
#  {'trip_distance': 9.8,
#   'pickup_latitude': 40.794829,
#   'pickup_longitude': -73.971476,
#   'distance_from_selected': 0.24223070036021363},
#  {'trip_distance': 1.05,
#   'pickup_latitude': 40.758647,
#   'pickup_longitude': -73.964878,
#   'distance_from_selected': 0.21604141184736217},
#  {'trip_distance': 0.74,
#   'pickup_latitude': 40.713638,
#   'pickup_longitude': -74.011587,
#   'distance_from_selected': 0.2404449185842875},
#  {'trip_distance': 8.4,
#   'pickup_latitude': 40.77403,
#   'pickup_longitude': -73.874597,
#   'distance_from_selected': 0.15932251381710127},
#  {'trip_distance': 5.1,
#   'pickup_latitude': 40.728127,
#   'pickup_longitude': -73.99887,
#   'distance_from_selected': 0.23305312520753735},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.759671,
#   'pickup_longitude': -73.976688,
#   'distance_from_selected': 0.22668665863918644},
#  {'trip_distance': 2.7,
#   'pickup_latitude': 40.772651,
#   'pickup_longitude': -73.967095,
#   'distance_from_selected': 0.22555015838168296},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.770319,
#   'pickup_longitude': -73.960222,
#   'distance_from_selected': 0.21857296133099804},
#  {'trip_distance': 1.12,
#   'pickup_latitude': 40.720457,
#   'pickup_longitude': -73.988065,
#   'distance_from_selected': 0.22024778163242495},
#  {'trip_distance': 16.0,
#   'pickup_latitude': 40.754789,
#   'pickup_longitude': -73.973606,
#   'distance_from_selected': 0.22157421406157182},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.755654,
#   'pickup_longitude': -73.985846,
#   'distance_from_selected': 0.23269502210403928},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.741568,
#   'pickup_longitude': -73.978341,
#   'distance_from_selected': 0.21957140197439562},
#  {'trip_distance': 0.74,
#   'pickup_latitude': 40.736907,
#   'pickup_longitude': -73.98862,
#   'distance_from_selected': 0.22691966814051334},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.76003,
#   'pickup_longitude': -73.964842,
#   'distance_from_selected': 0.21674167219065868},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.721366,
#   'pickup_longitude': -74.008287,
#   'distance_from_selected': 0.2396341172391779},
#  {'trip_distance': 1.97,
#   'pickup_latitude': 40.760147,
#   'pickup_longitude': -73.97627,
#   'distance_from_selected': 0.22656775818505578},
#  {'trip_distance': 0.96,
#   'pickup_latitude': 40.745847,
#   'pickup_longitude': -74.001817,
#   'distance_from_selected': 0.24262328688318888},
#  {'trip_distance': 0.74,
#   'pickup_latitude': 40.753015,
#   'pickup_longitude': -73.985247,
#   'distance_from_selected': 0.23092203453547114},
#  {'trip_distance': 12.7,
#   'pickup_latitude': 40.644657,
#   'pickup_longitude': -73.782229,
#   'distance_from_selected': 0.0011292165425673159},
#  {'trip_distance': 1.17,
#   'pickup_latitude': 40.738767,
#   'pickup_longitude': -74.0086,
#   'distance_from_selected': 0.2460236334765476},
#  {'trip_distance': 22.8,
#   'pickup_latitude': 40.773797,
#   'pickup_longitude': -73.871065,
#   'distance_from_selected': 0.15708580608699615},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.743411,
#   'pickup_longitude': -73.97686,
#   'distance_from_selected': 0.21906413978787692},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.758905,
#   'pickup_longitude': -73.967897,
#   'distance_from_selected': 0.21874887253194822},
#  {'trip_distance': 1.7,
#   'pickup_latitude': 40.733877,
#   'pickup_longitude': -73.989602,
#   'distance_from_selected': 0.22661230123937096},
#  {'trip_distance': 0.95,
#   'pickup_latitude': 40.726162,
#   'pickup_longitude': -73.983432,
#   'distance_from_selected': 0.21796077882958448},
#  {'trip_distance': 5.88,
#   'pickup_latitude': 40.775122,
#   'pickup_longitude': -73.947765,
#   'distance_from_selected': 0.21141167339814346},
#  {'trip_distance': 4.1,
#   'pickup_latitude': 40.75987,
#   'pickup_longitude': -73.978487,
#   'distance_from_selected': 0.22834032926533512},
#  {'trip_distance': 1.09,
#   'pickup_latitude': 40.707087,
#   'pickup_longitude': -73.94328,
#   'distance_from_selected': 0.17361501752153158},
#  {'trip_distance': 1.39,
#   'pickup_latitude': 40.741912,
#   'pickup_longitude': -74.003578,
#   'distance_from_selected': 0.24262747014302266},
#  {'trip_distance': 11.2,
#   'pickup_latitude': 40.769112,
#   'pickup_longitude': -73.862679,
#   'distance_from_selected': 0.14850336267236677},
#  {'trip_distance': 2.56,
#   'pickup_latitude': 40.785807,
#   'pickup_longitude': -73.976387,
#   'distance_from_selected': 0.2407216518263404},
#  {'trip_distance': 1.03,
#   'pickup_latitude': 40.7513,
#   'pickup_longitude': -73.986852,
#   'distance_from_selected': 0.23154940920676315},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.733385,
#   'pickup_longitude': -73.987204,
#   'distance_from_selected': 0.22421402039346996},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.760257,
#   'pickup_longitude': -73.976186,
#   'distance_from_selected': 0.22655136853482336},
#  {'trip_distance': 3.4,
#   'pickup_latitude': 40.741249,
#   'pickup_longitude': -74.005201,
#   'distance_from_selected': 0.24385373829818963},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.759795,
#   'pickup_longitude': -73.985352,
#   'distance_from_selected': 0.23426191502035304},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.756636,
#   'pickup_longitude': -73.9697,
#   'distance_from_selected': 0.2191253792147375},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.73925,
#   'pickup_longitude': -74.000759,
#   'distance_from_selected': 0.23898338955040813},
#  {'trip_distance': 1.07,
#   'pickup_latitude': 40.751055,
#   'pickup_longitude': -73.97607,
#   'distance_from_selected': 0.22190896923063805},
#  {'trip_distance': 3.9,
#   'pickup_latitude': 40.723584,
#   'pickup_longitude': -73.995992,
#   'distance_from_selected': 0.2287664787507171},
#  {'trip_distance': 14.43,
#   'pickup_latitude': 40.757037,
#   'pickup_longitude': -73.929485,
#   'distance_from_selected': 0.1858972900125233},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.743385,
#   'pickup_longitude': -73.981978,
#   'distance_from_selected': 0.2236368967970206},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.737486,
#   'pickup_longitude': -73.978153,
#   'distance_from_selected': 0.2176366054343872},
#  {'trip_distance': 1.76,
#   'pickup_latitude': 40.77225,
#   'pickup_longitude': -73.95285,
#   'distance_from_selected': 0.21371943664533735},
#  {'trip_distance': 2.45,
#   'pickup_latitude': 40.732882,
#   'pickup_longitude': -73.981975,
#   'distance_from_selected': 0.21921606758858478},
#  {'trip_distance': 2.03,
#   'pickup_latitude': 40.774567,
#   'pickup_longitude': -73.988232,
#   'distance_from_selected': 0.24428089088792698},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.757437,
#   'pickup_longitude': -73.964735,
#   'distance_from_selected': 0.2152853456090395},
#  {'trip_distance': 2.14,
#   'pickup_latitude': 40.789637,
#   'pickup_longitude': -73.975402,
#   'distance_from_selected': 0.24219123459159708},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.754317,
#   'pickup_longitude': -73.992548,
#   'distance_from_selected': 0.2379947632470118},
#  {'trip_distance': 0.44,
#   'pickup_latitude': 40.745007,
#   'pickup_longitude': -73.998627,
#   'distance_from_selected': 0.23937344426231005},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.734982,
#   'pickup_longitude': -73.990523,
#   'distance_from_selected': 0.22789386387746413},
#  {'trip_distance': 1.95,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance_from_selected': 84.23581962219279},
#  {'trip_distance': 1.48,
#   'pickup_latitude': 40.738617,
#   'pickup_longitude': -73.989672,
#   'distance_from_selected': 0.2285769883715342},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.790712,
#   'pickup_longitude': -73.972809,
#   'distance_from_selected': 0.24076559879891543},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.750167,
#   'pickup_longitude': -73.987398,
#   'distance_from_selected': 0.23151768578879758},
#  {'trip_distance': 12.7,
#   'pickup_latitude': 40.732141,
#   'pickup_longitude': -73.98447,
#   'distance_from_selected': 0.2212110286604215},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.765758,
#   'pickup_longitude': -73.994847,
#   'distance_from_selected': 0.24546143817919336},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.792594,
#   'pickup_longitude': -73.964102,
#   'distance_from_selected': 0.23507100016803525},
#  {'trip_distance': 1.8,
#   'pickup_latitude': 40.762908,
#   'pickup_longitude': -73.969549,
#   'distance_from_selected': 0.22225849348225643},
#  {'trip_distance': 4.85,
#   'pickup_latitude': 40.750722,
#   'pickup_longitude': -73.968447,
#   'distance_from_selected': 0.2150800363422906},
#  {'trip_distance': 5.09,
#   'pickup_latitude': 40.769887,
#   'pickup_longitude': -73.86443,
#   'distance_from_selected': 0.15011601849569428},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.77247,
#   'pickup_longitude': -73.982419,
#   'distance_from_selected': 0.23824432996610465},
#  {'trip_distance': 1.44,
#   'pickup_latitude': 40.764545,
#   'pickup_longitude': -73.982668,
#   'distance_from_selected': 0.23431368365719166},
#  {'trip_distance': 16.63,
#   'pickup_latitude': 40.641805,
#   'pickup_longitude': -73.78641,
#   'distance_from_selected': 0.006149132052581531},
#  {'trip_distance': 0.79,
#   'pickup_latitude': 40.75224,
#   'pickup_longitude': -73.97835,
#   'distance_from_selected': 0.22447806685732974},
#  {'trip_distance': 1.36,
#   'pickup_latitude': 40.758835,
#   'pickup_longitude': -73.988555,
#   'distance_from_selected': 0.23659568476623366},
#  {'trip_distance': 2.04,
#   'pickup_latitude': 40.722785,
#   'pickup_longitude': -73.988558,
#   'distance_from_selected': 0.22151781077150584},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.720338,
#   'pickup_longitude': -73.993645,
#   'distance_from_selected': 0.22545830241754564},
#  {'trip_distance': 1.65,
#   'pickup_latitude': 40.72973,
#   'pickup_longitude': -73.991628,
#   'distance_from_selected': 0.22689613501336778},
#  {'trip_distance': 0.64,
#   'pickup_latitude': 40.760442,
#   'pickup_longitude': -73.958405,
#   'distance_from_selected': 0.21153841100140727},
#  {'trip_distance': 1.34,
#   'pickup_latitude': 40.756227,
#   'pickup_longitude': -73.98314,
#   'distance_from_selected': 0.23059408116646082},
#  {'trip_distance': 1.13,
#   'pickup_latitude': 40.751555,
#   'pickup_longitude': -73.992905,
#   'distance_from_selected': 0.2370575441744035},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.71333,
#   'pickup_longitude': -74.004106,
#   'distance_from_selected': 0.23319462587289244},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.764762,
#   'pickup_longitude': -73.991849,
#   'distance_from_selected': 0.24236212696087986},
#  {'trip_distance': 1.9,
#   'pickup_latitude': 40.763353,
#   'pickup_longitude': -73.985259,
#   'distance_from_selected': 0.23594550991701782},
#  {'trip_distance': 0.66,
#   'pickup_latitude': 40.775292,
#   'pickup_longitude': -73.982082,
#   'distance_from_selected': 0.23948336023198694},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.779515,
#   'pickup_longitude': -73.984852,
#   'distance_from_selected': 0.24411366292979952},
#  {'trip_distance': 3.8,
#   'pickup_latitude': 40.768322,
#   'pickup_longitude': -73.982234,
#   'distance_from_selected': 0.23589310562202312},
#  {'trip_distance': 6.52,
#   'pickup_latitude': 40.766602,
#   'pickup_longitude': -73.95388,
#   'distance_from_selected': 0.21124661285805324},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.763684,
#   'pickup_longitude': -73.981214,
#   'distance_from_selected': 0.232623880399237},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.793086,
#   'pickup_longitude': -73.952092,
#   'distance_from_selected': 0.22617159985285412},
#  {'trip_distance': 3.4,
#   'pickup_latitude': 40.773602,
#   'pickup_longitude': -73.871055,
#   'distance_from_selected': 0.15692022039558665},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.771909,
#   'pickup_longitude': -73.959023,
#   'distance_from_selected': 0.21851141089197632},
#  {'trip_distance': 4.1,
#   'pickup_latitude': 40.774029,
#   'pickup_longitude': -73.961478,
#   'distance_from_selected': 0.22174140593267813},
#  {'trip_distance': 0.48,
#   'pickup_latitude': 40.74964,
#   'pickup_longitude': -73.972212,
#   'distance_from_selected': 0.21784469317383143},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.771542,
#   'pickup_longitude': -73.959533,
#   'distance_from_selected': 0.2187142048267509},
#  {'trip_distance': 3.89,
#   'pickup_latitude': 40.694095,
#   'pickup_longitude': -73.9839,
#   'distance_from_selected': 0.2086117530845358},
#  {'trip_distance': 6.98,
#   'pickup_latitude': 40.756312,
#   'pickup_longitude': -73.994315,
#   'distance_from_selected': 0.2404826499126326},
#  {'trip_distance': 1.8,
#   'pickup_latitude': 40.730282,
#   'pickup_longitude': -74.006652,
#   'distance_from_selected': 0.24109308838704416},
#  {'trip_distance': 0.97,
#   'pickup_latitude': 40.777707,
#   'pickup_longitude': -73.955068,
#   'distance_from_selected': 0.218772193875273},
#  {'trip_distance': 1.7,
#   'pickup_latitude': 40.726087,
#   'pickup_longitude': -73.994962,
#   'distance_from_selected': 0.22867508555372143},
#  {'trip_distance': 4.25,
#   'pickup_latitude': 40.738385,
#   'pickup_longitude': -73.999885,
#   'distance_from_selected': 0.23783949682507385},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.7678,
#   'pickup_longitude': -73.961987,
#   'distance_from_selected': 0.21859624120510202},
#  {'trip_distance': 0.12,
#   'pickup_latitude': 40.742682,
#   'pickup_longitude': -73.972513,
#   'distance_from_selected': 0.21485698646542573},
#  {'trip_distance': 1.02,
#   'pickup_latitude': 40.770602,
#   'pickup_longitude': -73.982262,
#   'distance_from_selected': 0.23711687221284533},
#  {'trip_distance': 2.39,
#   'pickup_latitude': 40.747967,
#   'pickup_longitude': -73.976727,
#   'distance_from_selected': 0.22103082467837062},
#  {'trip_distance': 1.6,
#   'pickup_latitude': 40.742803,
#   'pickup_longitude': -74.004093,
#   'distance_from_selected': 0.2434562881052793},
#  {'trip_distance': 1.7,
#   'pickup_latitude': 40.755521,
#   'pickup_longitude': -73.97546,
#   'distance_from_selected': 0.22354748502499638},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.760528,
#   'pickup_longitude': -74.002757,
#   'distance_from_selected': 0.24991737013061496},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.740732,
#   'pickup_longitude': -74.005513,
#   'distance_from_selected': 0.2439370540385343},
#  {'trip_distance': 1.11,
#   'pickup_latitude': 40.735497,
#   'pickup_longitude': -74.00601,
#   'distance_from_selected': 0.24239128831087028},
#  {'trip_distance': 6.01,
#   'pickup_latitude': 40.715387,
#   'pickup_longitude': -74.013518,
#   'distance_from_selected': 0.2427974979957655},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.721587,
#   'pickup_longitude': -73.995427,
#   'distance_from_selected': 0.22755600000440362},
#  {'trip_distance': 1.26,
#   'pickup_latitude': 40.760057,
#   'pickup_longitude': -73.983502,
#   'distance_from_selected': 0.23278046823778556},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.740332,
#   'pickup_longitude': -73.986289,
#   'distance_from_selected': 0.22621252459800165},
#  {'trip_distance': 5.4,
#   'pickup_latitude': 40.7455,
#   'pickup_longitude': -73.977834,
#   'distance_from_selected': 0.2208774681944762},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.733125,
#   'pickup_longitude': -73.987273,
#   'distance_from_selected': 0.22417508638116398},
#  {'trip_distance': 3.2,
#   'pickup_latitude': 40.752092,
#   'pickup_longitude': -73.989949,
#   'distance_from_selected': 0.23466542311341715},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.72381,
#   'pickup_longitude': -73.992617,
#   'distance_from_selected': 0.22567871961928446},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.767446,
#   'pickup_longitude': -73.984105,
#   'distance_from_selected': 0.23703629249758587},
#  {'trip_distance': 2.0,
#   'pickup_latitude': 40.800479,
#   'pickup_longitude': -73.968083,
#   'distance_from_selected': 0.24314764158839683},
#  {'trip_distance': 0.88,
#   'pickup_latitude': 40.717055,
#   'pickup_longitude': -73.991325,
#   'distance_from_selected': 0.22218662167196992},
#  {'trip_distance': 0.88,
#   'pickup_latitude': 40.748863,
#   'pickup_longitude': -73.992155,
#   'distance_from_selected': 0.23518654330977373},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.80474,
#   'pickup_longitude': -73.9478,
#   'distance_from_selected': 0.23085121832037664},
#  {'trip_distance': 1.23,
#   'pickup_latitude': 40.762202,
#   'pickup_longitude': -73.969015,
#   'distance_from_selected': 0.2214315044635729},
#  {'trip_distance': 5.19,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance_from_selected': 84.23581962219279},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.740407,
#   'pickup_longitude': -73.987223,
#   'distance_from_selected': 0.22709135874797393},
#  {'trip_distance': 5.6,
#   'pickup_latitude': 40.722399,
#   'pickup_longitude': -73.997097,
#   'distance_from_selected': 0.22940196182683445},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.747572,
#   'pickup_longitude': -73.974092,
#   'distance_from_selected': 0.21851700640453697},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.794651,
#   'pickup_longitude': -73.972048,
#   'distance_from_selected': 0.24257052855819514},
#  {'trip_distance': 0.06,
#   'pickup_latitude': 40.751087,
#   'pickup_longitude': -73.9716,
#   'distance_from_selected': 0.21800866016972595},
#  {'trip_distance': 3.9,
#   'pickup_latitude': 40.719886,
#   'pickup_longitude': -74.009981,
#   'distance_from_selected': 0.24077590696953086},
#  {'trip_distance': 0.73,
#   'pickup_latitude': 40.760887,
#   'pickup_longitude': -73.98696,
#   'distance_from_selected': 0.23619879489319817},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.727514,
#   'pickup_longitude': -74.0073,
#   'distance_from_selected': 0.2407364390282488},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.774453,
#   'pickup_longitude': -73.872166,
#   'distance_from_selected': 0.1582547965307915},
#  {'trip_distance': 4.9,
#   'pickup_latitude': 40.741907,
#   'pickup_longitude': -74.003545,
#   'distance_from_selected': 0.24259522030329075},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.735118,
#   'pickup_longitude': -73.97979,
#   'distance_from_selected': 0.21813047926412987},
#  {'trip_distance': 8.73,
#   'pickup_latitude': 40.773907,
#   'pickup_longitude': -73.871275,
#   'distance_from_selected': 0.15729624443705073},
#  {'trip_distance': 1.48,
#   'pickup_latitude': 40.758937,
#   'pickup_longitude': -73.994232,
#   'distance_from_selected': 0.24163579522289472},
#  {'trip_distance': 0.4,
#   'pickup_latitude': 40.752144,
#   'pickup_longitude': -73.977199,
#   'distance_from_selected': 0.2234215524899089},
#  {'trip_distance': 0.61,
#   'pickup_latitude': 40.745642,
#   'pickup_longitude': -73.990757,
#   'distance_from_selected': 0.23252079380778312},
#  {'trip_distance': 1.92,
#   'pickup_latitude': 40.71879,
#   'pickup_longitude': -73.98984,
#   'distance_from_selected': 0.22135481946413899},
#  {'trip_distance': 1.9,
#   'pickup_latitude': 40.739945,
#   'pickup_longitude': -74.006124,
#   'distance_from_selected': 0.24419204061762775},
#  {'trip_distance': 1.85,
#   'pickup_latitude': 40.777575,
#   'pickup_longitude': -73.986287,
#   'distance_from_selected': 0.24425390681420603},
#  {'trip_distance': 1.6,
#   'pickup_latitude': 40.753632,
#   'pickup_longitude': -73.988899,
#   'distance_from_selected': 0.23444131710303018},
#  {'trip_distance': 3.61,
#   'pickup_latitude': 40.74733,
#   'pickup_longitude': -73.97703,
#   'distance_from_selected': 0.22100328051863977},
#  {'trip_distance': 0.4,
#   'pickup_latitude': 40.769822,
#   'pickup_longitude': -73.960596,
#   'distance_from_selected': 0.2185952770304038},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.724658,
#   'pickup_longitude': -73.997131,
#   'distance_from_selected': 0.2302059568842635},
#  {'trip_distance': 1.21,
#   'pickup_latitude': 40.758345,
#   'pickup_longitude': -73.989398,
#   'distance_from_selected': 0.2371003701578693},
#  {'trip_distance': 0.55,
#   'pickup_latitude': 40.764807,
#   'pickup_longitude': -73.97669,
#   'distance_from_selected': 0.22932946842698315},
#  {'trip_distance': 1.27,
#   'pickup_latitude': 40.772847,
#   'pickup_longitude': -73.962703,
#   'distance_from_selected': 0.22205608358701326},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.793682,
#   'pickup_longitude': -73.966972,
#   'distance_from_selected': 0.23798976143523426},
#  {'trip_distance': 4.5,
#   'pickup_latitude': 40.760007,
#   'pickup_longitude': -73.97804,
#   'distance_from_selected': 0.22802320581247626},
#  {'trip_distance': 1.52,
#   'pickup_latitude': 40.747252,
#   'pickup_longitude': -73.888215,
#   'distance_from_selected': 0.14805549928659145},
#  {'trip_distance': 2.6,
#   'pickup_latitude': 40.756392,
#   'pickup_longitude': -73.967522,
#   'distance_from_selected': 0.21712882809061018},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.763685,
#   'pickup_longitude': -73.977714,
#   'distance_from_selected': 0.2296212296827195},
#  {'trip_distance': 3.4,
#   'pickup_latitude': 40.767068,
#   'pickup_longitude': -73.982805,
#   'distance_from_selected': 0.23572818479978463},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.77596,
#   'pickup_longitude': -73.98728,
#   'distance_from_selected': 0.24421858610679106},
#  {'trip_distance': 1.44,
#   'pickup_latitude': 40.739617,
#   'pickup_longitude': -73.984663,
#   'distance_from_selected': 0.22443665096859935},
#  {'trip_distance': 10.9,
#   'pickup_latitude': 40.751953,
#   'pickup_longitude': -73.976404,
#   'distance_from_selected': 0.22263245020661804},
#  {'trip_distance': 2.8,
#   'pickup_latitude': 40.718635,
#   'pickup_longitude': -74.000952,
#   'distance_from_selected': 0.23181135698882502},
#  {'trip_distance': 2.67,
#   'pickup_latitude': 40.7331,
#   'pickup_longitude': -73.981375,
#   'distance_from_selected': 0.21875425190153755},
#  {'trip_distance': 0.84,
#   'pickup_latitude': 40.77463,
#   'pickup_longitude': -73.96322,
#   'distance_from_selected': 0.22350842154157013},
#  {'trip_distance': 1.89,
#   'pickup_latitude': 40.753675,
#   'pickup_longitude': -73.984942,
#   'distance_from_selected': 0.23096235296905676},
#  {'trip_distance': 2.61,
#   'pickup_latitude': 40.763262,
#   'pickup_longitude': -73.95948,
#   'distance_from_selected': 0.21398564177065785},
#  {'trip_distance': 1.29,
#   'pickup_latitude': 40.768895,
#   'pickup_longitude': -73.958237,
#   'distance_from_selected': 0.21613017973897172},
#  {'trip_distance': 11.5,
#   'pickup_latitude': 40.641375,
#   'pickup_longitude': -73.788935,
#   'distance_from_selected': 0.008583382200508133},
#  {'trip_distance': 1.21,
#   'pickup_latitude': 40.745472,
#   'pickup_longitude': -73.98666,
#   'distance_from_selected': 0.22875968268906452},
#  {'trip_distance': 2.33,
#   'pickup_latitude': 40.707562,
#   'pickup_longitude': -74.004372,
#   'distance_from_selected': 0.23182604786348632},
#  {'trip_distance': 1.05,
#   'pickup_latitude': 40.75331,
#   'pickup_longitude': -73.968992,
#   'distance_from_selected': 0.21683597340847544},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.769545,
#   'pickup_longitude': -73.960554,
#   'distance_from_selected': 0.21840270886827864},
#  {'trip_distance': 9.37,
#   'pickup_latitude': 40.77411,
#   'pickup_longitude': -73.874625,
#   'distance_from_selected': 0.15940373278251582},
#  {'trip_distance': 1.77,
#   'pickup_latitude': 40.720615,
#   'pickup_longitude': -74.009875,
#   'distance_from_selected': 0.24090302250075454},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.76305,
#   'pickup_longitude': -73.969831,
#   'distance_from_selected': 0.22257287202397538},
#  {'trip_distance': 18.2,
#   'pickup_latitude': 40.648605,
#   'pickup_longitude': -73.78482,
#   'distance_from_selected': 0.005151419707228516},
#  {'trip_distance': 2.29,
#   'pickup_latitude': 40.730875,
#   'pickup_longitude': -74.001527,
#   'distance_from_selected': 0.23652115202239146},
#  {'trip_distance': 3.1,
#   'pickup_latitude': 40.763843,
#   'pickup_longitude': -73.928025,
#   'distance_from_selected': 0.18893994081189622},
#  {'trip_distance': 1.9,
#   'pickup_latitude': 40.759867,
#   'pickup_longitude': -73.97835,
#   'distance_from_selected': 0.22822043100696238},
#  {'trip_distance': 0.94,
#   'pickup_latitude': 40.77302,
#   'pickup_longitude': -73.982,
#   'distance_from_selected': 0.23818564902193773},
#  {'trip_distance': 2.7,
#   'pickup_latitude': 40.767437,
#   'pickup_longitude': -73.980957,
#   'distance_from_selected': 0.23434185511342837},
#  {'trip_distance': 0.2,
#   'pickup_latitude': 40.7951,
#   'pickup_longitude': -73.97166,
#   'distance_from_selected': 0.24254292857141938},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.78045,
#   'pickup_longitude': -73.980198,
#   'distance_from_selected': 0.2407685982515212},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.777608,
#   'pickup_longitude': -73.956815,
#   'distance_from_selected': 0.22010389853204207},
#  {'trip_distance': 2.5,
#   'pickup_latitude': 40.783897,
#   'pickup_longitude': -73.952306,
#   'distance_from_selected': 0.22043033136344833},
#  {'trip_distance': 0.3,
#   'pickup_latitude': 40.738437,
#   'pickup_longitude': -73.999686,
#   'distance_from_selected': 0.23767693431420658},
#  {'trip_distance': 2.61,
#   'pickup_latitude': 40.766227,
#   'pickup_longitude': -73.980152,
#   'distance_from_selected': 0.23302404634072219},
#  {'trip_distance': 3.2,
#   'pickup_latitude': 40.7472,
#   'pickup_longitude': -74.007947,
#   'distance_from_selected': 0.2487644735668702},
#  {'trip_distance': 1.63,
#   'pickup_latitude': 40.729602,
#   'pickup_longitude': -73.987032,
#   'distance_from_selected': 0.22259062978481606},
#  {'trip_distance': 1.86,
#   'pickup_latitude': 40.747295,
#   'pickup_longitude': -74.000877,
#   'distance_from_selected': 0.2423762933003203},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.764276,
#   'pickup_longitude': -73.954283,
#   'distance_from_selected': 0.2102479143416244},
#  {'trip_distance': 2.0,
#   'pickup_latitude': 40.717463,
#   'pickup_longitude': -74.005494,
#   'distance_from_selected': 0.23575955137597557},
#  {'trip_distance': 3.06,
#   'pickup_latitude': 40.756667,
#   'pickup_longitude': -73.967298,
#   'distance_from_selected': 0.2170779358502405},
#  {'trip_distance': 3.4,
#   'pickup_latitude': 40.723036,
#   'pickup_longitude': -73.988783,
#   'distance_from_selected': 0.22181668288251138},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.742832,
#   'pickup_longitude': -73.989064,
#   'distance_from_selected': 0.22978530927803237},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.759825,
#   'pickup_longitude': -73.970231,
#   'distance_from_selected': 0.2212209343303668},
#  {'trip_distance': 3.8,
#   'pickup_latitude': 40.770567,
#   'pickup_longitude': -73.954641,
#   'distance_from_selected': 0.21416981582379774},
#  {'trip_distance': 0.73,
#   'pickup_latitude': 40.743565,
#   'pickup_longitude': -73.988827,
#   'distance_from_selected': 0.22988424685915512},
#  {'trip_distance': 0.58,
#   'pickup_latitude': 40.761372,
#   'pickup_longitude': -73.982602,
#   'distance_from_selected': 0.23265355838241908},
#  {'trip_distance': 0.06,
#   'pickup_latitude': 40.725012,
#   'pickup_longitude': -73.995492,
#   'distance_from_selected': 0.22879251178305815},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.751251,
#   'pickup_longitude': -73.975745,
#   'distance_from_selected': 0.22171741958178065},
#  {'trip_distance': 0.64,
#   'pickup_latitude': 40.742522,
#   'pickup_longitude': -73.993292,
#   'distance_from_selected': 0.23348815641912168},
#  {'trip_distance': 1.72,
#   'pickup_latitude': 40.762107,
#   'pickup_longitude': -73.98479,
#   'distance_from_selected': 0.23491624313572484},
#  {'trip_distance': 0.2,
#   'pickup_latitude': 40.787171,
#   'pickup_longitude': -73.953967,
#   'distance_from_selected': 0.22378818612697893},
#  {'trip_distance': 0.87,
#   'pickup_latitude': 40.739887,
#   'pickup_longitude': -74.004942,
#   'distance_from_selected': 0.24308085048601005},
#  {'trip_distance': 2.47,
#   'pickup_latitude': 40.775297,
#   'pickup_longitude': -73.982005,
#   'distance_from_selected': 0.23942148039389072},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.743232,
#   'pickup_longitude': -73.983751,
#   'distance_from_selected': 0.2251636199855571},
#  {'trip_distance': 1.9,
#   'pickup_latitude': 40.757386,
#   'pickup_longitude': -73.987253,
#   'distance_from_selected': 0.23475797627556513},
#  {'trip_distance': 0.57,
#   'pickup_latitude': 40.749027,
#   'pickup_longitude': -73.98395,
#   'distance_from_selected': 0.22792879890219692},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.752385,
#   'pickup_longitude': -73.978314,
#   'distance_from_selected': 0.22451576541748605},
#  {'trip_distance': 4.0,
#   'pickup_latitude': 40.721988,
#   'pickup_longitude': -73.986383,
#   'distance_from_selected': 0.21920145139346892},
#  {'trip_distance': 1.04,
#   'pickup_latitude': 40.742422,
#   'pickup_longitude': -73.991082,
#   'distance_from_selected': 0.23143992578637632},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.735396,
#   'pickup_longitude': -73.993911,
#   'distance_from_selected': 0.2311719878294091},
#  {'trip_distance': 3.3,
#   'pickup_latitude': 40.749873,
#   'pickup_longitude': -73.991593,
#   'distance_from_selected': 0.23513123981725467},
#  {'trip_distance': 1.35,
#   'pickup_latitude': 40.779447,
#   'pickup_longitude': -73.962047,
#   'distance_from_selected': 0.2253938984489153},
#  {'trip_distance': 5.0,
#   'pickup_latitude': 40.730843,
#   'pickup_longitude': -74.00677,
#   'distance_from_selected': 0.24140240680035258},
#  {'trip_distance': 2.0,
#   'pickup_latitude': 40.750116,
#   'pickup_longitude': -73.987503,
#   'distance_from_selected': 0.23158807500603873},
#  {'trip_distance': 5.2,
#   'pickup_latitude': 40.701734,
#   'pickup_longitude': -74.011263,
#   'distance_from_selected': 0.23700606385702783},
#  {'trip_distance': 2.2,
#   'pickup_latitude': 40.72635,
#   'pickup_longitude': -73.977049,
#   'distance_from_selected': 0.21212229444591232},
#  {'trip_distance': 5.5,
#   'pickup_latitude': 40.688702,
#   'pickup_longitude': -73.98921,
#   'distance_from_selected': 0.2126022166958785},
#  {'trip_distance': 1.49,
#   'pickup_latitude': 40.771385,
#   'pickup_longitude': -73.96467,
#   'distance_from_selected': 0.22283466163279245},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.715884,
#   'pickup_longitude': -73.959979,
#   'distance_from_selected': 0.19236883967265345},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.790046,
#   'pickup_longitude': -73.975066,
#   'distance_from_selected': 0.24216659181645936},
#  {'trip_distance': 1.44,
#   'pickup_latitude': 40.76418,
#   'pickup_longitude': -73.97822,
#   'distance_from_selected': 0.23031031457579013},
#  {'trip_distance': 5.3,
#   'pickup_latitude': 40.76041,
#   'pickup_longitude': -73.987652,
#   'distance_from_selected': 0.23656891681706674},
#  {'trip_distance': 0.43,
#   'pickup_latitude': 40.745647,
#   'pickup_longitude': -73.978275,
#   'distance_from_selected': 0.22133706710354584},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.793261,
#   'pickup_longitude': -73.940565,
#   'distance_from_selected': 0.21770951211649775},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.762111,
#   'pickup_longitude': -73.968438,
#   'distance_from_selected': 0.22089391930291544},
#  {'trip_distance': 1.65,
#   'pickup_latitude': 40.74733,
#   'pickup_longitude': -73.9969,
#   'distance_from_selected': 0.2387918300528717},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.74886,
#   'pickup_longitude': -73.988666,
#   'distance_from_selected': 0.23206005075410846},
#  {'trip_distance': 2.0,
#   'pickup_latitude': 40.730145,
#   'pickup_longitude': -73.986395,
#   'distance_from_selected': 0.22220909983617257},
#  {'trip_distance': 6.6,
#   'pickup_latitude': 40.75318,
#   'pickup_longitude': -73.973152,
#   'distance_from_selected': 0.22038567127651687},
#  {'trip_distance': 1.9,
#   'pickup_latitude': 40.829557,
#   'pickup_longitude': -73.837699,
#   'distance_from_selected': 0.19303566222333352},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.743102,
#   'pickup_longitude': -73.973988,
#   'distance_from_selected': 0.21636186999562454},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.750445,
#   'pickup_longitude': -73.98674,
#   'distance_from_selected': 0.23105844525790475},
#  {'trip_distance': 8.26,
#   'pickup_latitude': 40.743475,
#   'pickup_longitude': -73.923155,
#   'distance_from_selected': 0.17281410605039918},
#  {'trip_distance': 1.03,
#   'pickup_latitude': 40.762752,
#   'pickup_longitude': -73.993035,
#   'distance_from_selected': 0.24241110096075175},
#  {'trip_distance': 3.02,
#   'pickup_latitude': 40.765577,
#   'pickup_longitude': -73.979713,
#   'distance_from_selected': 0.23231119115962312},
#  {'trip_distance': 0.98,
#   'pickup_latitude': 40.750027,
#   'pickup_longitude': -73.89876,
#   'distance_from_selected': 0.1576860281350266},
#  {'trip_distance': 1.13,
#   'pickup_latitude': 40.751947,
#   'pickup_longitude': -73.986142,
#   'distance_from_selected': 0.23121747320002015},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.71972,
#   'pickup_longitude': -74.008841,
#   'distance_from_selected': 0.2396409071527723},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.78079,
#   'pickup_longitude': -73.946522,
#   'distance_from_selected': 0.213984902233785},
#  {'trip_distance': 0.4,
#   'pickup_latitude': 40.751607,
#   'pickup_longitude': -73.993449,
#   'distance_from_selected': 0.23756693812481705},
#  {'trip_distance': 1.36,
#   'pickup_latitude': 40.745595,
#   'pickup_longitude': -73.988398,
#   'distance_from_selected': 0.23037599599134284},
#  {'trip_distance': 7.46,
#   'pickup_latitude': 40.72245,
#   'pickup_longitude': -73.98729,
#   'distance_from_selected': 0.22021296782887773},
#  {'trip_distance': 3.03,
#   'pickup_latitude': 40.702557,
#   'pickup_longitude': -73.93467,
#   'distance_from_selected': 0.1639583785263808},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.734659,
#   'pickup_longitude': -73.98004,
#   'distance_from_selected': 0.21816911252742086},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.764774,
#   'pickup_longitude': -73.992049,
#   'distance_from_selected': 0.2425419445312495},
#  {'trip_distance': 0.4,
#   'pickup_latitude': 40.723516,
#   'pickup_longitude': -73.985065,
#   'distance_from_selected': 0.21851237928548395},
#  {'trip_distance': 1.88,
#   'pickup_latitude': 40.781072,
#   'pickup_longitude': -73.983538,
#   'distance_from_selected': 0.24388360598449446},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.793005,
#   'pickup_longitude': -73.973026,
#   'distance_from_selected': 0.24233208537253836},
#  {'trip_distance': 5.29,
#   'pickup_latitude': 40.721025,
#   'pickup_longitude': -73.993857,
#   'distance_from_selected': 0.22588844386998502},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.768497,
#   'pickup_longitude': -73.899785,
#   'distance_from_selected': 0.1712549043794084},
#  {'trip_distance': 0.0,
#   'pickup_latitude': 40.80726,
#   'pickup_longitude': -73.954179,
#   'distance_from_selected': 0.23721422331091302},
#  {'trip_distance': 1.72,
#   'pickup_latitude': 40.773715,
#   'pickup_longitude': -73.963908,
#   'distance_from_selected': 0.22354107494821449},
#  {'trip_distance': 1.42,
#   'pickup_latitude': 40.780082,
#   'pickup_longitude': -73.956843,
#   'distance_from_selected': 0.2216255371409248},
#  {'trip_distance': 7.4,
#   'pickup_latitude': 40.741824,
#   'pickup_longitude': -73.982933,
#   'distance_from_selected': 0.22381510816967357},
#  {'trip_distance': 3.12,
#   'pickup_latitude': 40.742112,
#   'pickup_longitude': -74.004672,
#   'distance_from_selected': 0.2437104170280806},
#  {'trip_distance': 5.4,
#   'pickup_latitude': 40.725925,
#   'pickup_longitude': -74.007585,
#   'distance_from_selected': 0.24046472392017015},
#  {'trip_distance': 20.5,
#   'pickup_latitude': 40.645718,
#   'pickup_longitude': -73.776765,
#   'distance_from_selected': 0.004445020697364217},
#  {'trip_distance': 9.4,
#   'pickup_latitude': 40.718398,
#   'pickup_longitude': -73.994967,
#   'distance_from_selected': 0.2260673438447106},
#  {'trip_distance': 2.8,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance_from_selected': 84.23581962219279},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.736343,
#   'pickup_longitude': -73.99289,
#   'distance_from_selected': 0.2306061538836338},
#  {'trip_distance': 17.65,
#   'pickup_latitude': 40.753827,
#   'pickup_longitude': -73.994472,
#   'distance_from_selected': 0.2394822921491325},
#  {'trip_distance': 1.8,
#   'pickup_latitude': 40.750693,
#   'pickup_longitude': -73.971834,
#   'distance_from_selected': 0.2180218155712895},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.745964,
#   'pickup_longitude': -73.991152,
#   'distance_from_selected': 0.2330162841519909},
#  {'trip_distance': 1.93,
#   'pickup_latitude': 40.740482,
#   'pickup_longitude': -74.004042,
#   'distance_from_selected': 0.2424862176042192},
#  {'trip_distance': 0.3,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance_from_selected': 84.23581962219279},
#  {'trip_distance': 8.74,
#   'pickup_latitude': 40.803842,
#   'pickup_longitude': -73.966812,
#   'distance_from_selected': 0.24434470763248356},
#  {'trip_distance': 0.73,
#   'pickup_latitude': 40.797632,
#   'pickup_longitude': -73.969822,
#   'distance_from_selected': 0.24268643091033923},
#  {'trip_distance': 19.05,
#   'pickup_latitude': 40.645322,
#   'pickup_longitude': -73.776652,
#   'distance_from_selected': 0.0045102359140052955},
#  {'trip_distance': 0.75,
#   'pickup_latitude': 40.749207,
#   'pickup_longitude': -74.003233,
#   'distance_from_selected': 0.24532028448132598},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.765548,
#   'pickup_longitude': -73.983683,
#   'distance_from_selected': 0.23569863693496754},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.760289,
#   'pickup_longitude': -73.931531,
#   'distance_from_selected': 0.1894948668486909},
#  {'trip_distance': 3.6,
#   'pickup_latitude': 40.778967,
#   'pickup_longitude': -73.981767,
#   'distance_from_selected': 0.2412405795425051},
#  {'trip_distance': 3.59,
#   'pickup_latitude': 40.7582,
#   'pickup_longitude': -73.973285,
#   'distance_from_selected': 0.22300753871787246},
#  {'trip_distance': 2.5,
#   'pickup_latitude': 40.730709,
#   'pickup_longitude': -73.990504,
#   'distance_from_selected': 0.22622299679078062},
#  {'trip_distance': 1.29,
#   'pickup_latitude': 40.7456,
#   'pickup_longitude': -73.97814,
#   'distance_from_selected': 0.22119546152667885},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.719471,
#   'pickup_longitude': -73.999779,
#   'distance_from_selected': 0.23096765791340332},
#  {'trip_distance': 1.03,
#   'pickup_latitude': 40.75619,
#   'pickup_longitude': -73.974282,
#   'distance_from_selected': 0.22285737462332592},
#  {'trip_distance': 3.08,
#   'pickup_latitude': 40.639542,
#   'pickup_longitude': -73.967915,
#   'distance_from_selected': 0.1868444431311863},
#  {'trip_distance': 1.77,
#   'pickup_latitude': 40.78366,
#   'pickup_longitude': -73.97427,
#   'distance_from_selected': 0.23774924458345234},
#  {'trip_distance': 0.74,
#   'pickup_latitude': 40.7464,
#   'pickup_longitude': -73.97771,
#   'distance_from_selected': 0.22117825774700892},
#  {'trip_distance': 3.98,
#   'pickup_latitude': 40.727475,
#   'pickup_longitude': -73.98533,
#   'distance_from_selected': 0.22021182444410883},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.735015,
#   'pickup_longitude': -74.006024,
#   'distance_from_selected': 0.2422247231415476},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance_from_selected': 84.23581962219279},
#  {'trip_distance': 1.33,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance_from_selected': 84.23581962219279},
#  {'trip_distance': 1.8,
#   'pickup_latitude': 40.754176,
#   'pickup_longitude': -74.04442,
#   'distance_from_selected': 0.2850134654643588},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.740112,
#   'pickup_longitude': -73.994987,
#   'distance_from_selected': 0.2340394356791176},
#  {'trip_distance': 2.07,
#   'pickup_latitude': 40.719972,
#   'pickup_longitude': -73.987553,
#   'distance_from_selected': 0.21960077124865343},
#  {'trip_distance': 2.43,
#   'pickup_latitude': 40.70517,
#   'pickup_longitude': -74.006987,
#   'distance_from_selected': 0.23371774209289212},
#  {'trip_distance': 2.18,
#   'pickup_latitude': 40.789142,
#   'pickup_longitude': -73.970472,
#   'distance_from_selected': 0.23795507724778872},
#  {'trip_distance': 4.72,
#   'pickup_latitude': 40.749115,
#   'pickup_longitude': -73.984182,
#   'distance_from_selected': 0.22817539010376145},
#  {'trip_distance': 2.15,
#   'pickup_latitude': 40.76443,
#   'pickup_longitude': -73.992037,
#   'distance_from_selected': 0.24236179643045888},
#  {'trip_distance': 3.5,
#   'pickup_latitude': 40.756477,
#   'pickup_longitude': -73.990472,
#   'distance_from_selected': 0.23716039056511815},
#  {'trip_distance': 1.52,
#   'pickup_latitude': 40.746142,
#   'pickup_longitude': -73.984852,
#   'distance_from_selected': 0.22743401660262397},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.747856,
#   'pickup_longitude': -73.989088,
#   'distance_from_selected': 0.23199057265328515},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.772615,
#   'pickup_longitude': -73.964789,
#   'distance_from_selected': 0.22363233877505345},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.761912,
#   'pickup_longitude': -73.975275,
#   'distance_from_selected': 0.22661701107595703},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.740991,
#   'pickup_longitude': -74.005581,
#   'distance_from_selected': 0.24410134322040225},
#  {'trip_distance': 3.84,
#   'pickup_latitude': 40.764115,
#   'pickup_longitude': -73.97707,
#   'distance_from_selected': 0.2292932882249274},
#  {'trip_distance': 16.4,
#   'pickup_latitude': 40.728808,
#   'pickup_longitude': -73.987538,
#   'distance_from_selected': 0.2227587566584124},
#  {'trip_distance': 4.2,
#   'pickup_latitude': 40.725511,
#   'pickup_longitude': -73.991953,
#   'distance_from_selected': 0.2256580072809271},
#  {'trip_distance': 1.09,
#   'pickup_latitude': 40.768967,
#   'pickup_longitude': -73.954822,
#   'distance_from_selected': 0.21338289554929088},
#  {'trip_distance': 2.7,
#   'pickup_latitude': 40.75652,
#   'pickup_longitude': -73.973926,
#   'distance_from_selected': 0.2227140028736495},
#  {'trip_distance': 0.88,
#   'pickup_latitude': 40.751217,
#   'pickup_longitude': -73.970895,
#   'distance_from_selected': 0.21745652566432705},
#  {'trip_distance': 1.09,
#   'pickup_latitude': 40.779557,
#   'pickup_longitude': -73.977187,
#   'distance_from_selected': 0.23777885284019848},
#  {'trip_distance': 12.06,
#   'pickup_latitude': 40.771472,
#   'pickup_longitude': -73.8755,
#   'distance_from_selected': 0.15779613057360375},
#  {'trip_distance': 0.45,
#   'pickup_latitude': 40.73832,
#   'pickup_longitude': -73.9918,
#   'distance_from_selected': 0.23039946050284227},
#  {'trip_distance': 19.03,
#   'pickup_latitude': 40.643172,
#   'pickup_longitude': -73.789035,
#   'distance_from_selected': 0.008091869314319596},
#  {'trip_distance': 0.45,
#   'pickup_latitude': 40.769387,
#   'pickup_longitude': -73.953623,
#   'distance_from_selected': 0.21265358999555892},
#  {'trip_distance': 1.28,
#   'pickup_latitude': 40.731752,
#   'pickup_longitude': -74.000932,
#   'distance_from_selected': 0.23628747780617598},
#  {'trip_distance': 16.1,
#   'pickup_latitude': 40.745874,
#   'pickup_longitude': -73.991095,
#   'distance_from_selected': 0.23292592058635747},
#  {'trip_distance': 0.2,
#   'pickup_latitude': 40.767867,
#   'pickup_longitude': -73.963893,
#   'distance_from_selected': 0.220212990484216},
#  {'trip_distance': 1.04,
#   'pickup_latitude': 40.766245,
#   'pickup_longitude': -73.98354,
#   'distance_from_selected': 0.23593322598778418},
#  {'trip_distance': 0.76,
#   'pickup_latitude': 40.753485,
#   'pickup_longitude': -73.97311,
#   'distance_from_selected': 0.22049899461222697},
#  {'trip_distance': 1.26,
#   'pickup_latitude': 40.726597,
#   'pickup_longitude': -73.986165,
#   'distance_from_selected': 0.2206600386884788},
#  {'trip_distance': 0.59,
#   'pickup_latitude': 40.7446,
#   'pickup_longitude': -73.985232,
#   'distance_from_selected': 0.22709384585232498},
#  {'trip_distance': 2.8,
#   'pickup_latitude': 40.756806,
#   'pickup_longitude': -73.969385,
#   'distance_from_selected': 0.2189411635143142},
#  {'trip_distance': 1.42,
#   'pickup_latitude': 40.783447,
#   'pickup_longitude': -73.947283,
#   'distance_from_selected': 0.21626491749241572},
#  {'trip_distance': 6.13,
#   'pickup_latitude': 40.758985,
#   'pickup_longitude': -73.989435,
#   'distance_from_selected': 0.23743946860200418},
#  {'trip_distance': 17.5,
#   'pickup_latitude': 40.645316,
#   'pickup_longitude': -73.776808,
#   'distance_from_selected': 0.004354220940644754},
#  {'trip_distance': 8.3,
#   'pickup_latitude': 40.762868,
#   'pickup_longitude': -73.983233,
#   'distance_from_selected': 0.23395034039941068},
#  {'trip_distance': 0.65,
#   'pickup_latitude': 40.761322,
#   'pickup_longitude': -73.975755,
#   'distance_from_selected': 0.22672503225052992},
#  {'trip_distance': 9.61,
#   'pickup_latitude': 40.771097,
#   'pickup_longitude': -73.865913,
#   'distance_from_selected': 0.15194650906816182},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.760195,
#   'pickup_longitude': -73.967307,
#   'distance_from_selected': 0.21892149431703573},
#  {'trip_distance': 4.92,
#   'pickup_latitude': 40.73286,
#   'pickup_longitude': -74.00007,
#   'distance_from_selected': 0.23589638254962528},
#  {'trip_distance': 2.4,
#   'pickup_latitude': 40.75952,
#   'pickup_longitude': -73.985488,
#   'distance_from_selected': 0.2342458946150462},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.821517,
#   'pickup_longitude': -73.954177,
#   'distance_from_selected': 0.24718439363762768},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.734922,
#   'pickup_longitude': -73.990548,
#   'distance_from_selected': 0.22789314826910134},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.757594,
#   'pickup_longitude': -73.989531,
#   'distance_from_selected': 0.23685924507394812},
#  {'trip_distance': 0.63,
#   'pickup_latitude': 40.748042,
#   'pickup_longitude': -73.880385,
#   'distance_from_selected': 0.1430639714568314},
#  {'trip_distance': 6.04,
#   'pickup_latitude': 40.74957,
#   'pickup_longitude': -73.992772,
#   'distance_from_selected': 0.2360526366808938},
#  {'trip_distance': 2.2,
#   'pickup_latitude': 40.759663,
#   'pickup_longitude': -73.981141,
#   'distance_from_selected': 0.23053480650435332},
#  {'trip_distance': 1.85,
#   'pickup_latitude': 40.756397,
#   'pickup_longitude': -73.966882,
#   'distance_from_selected': 0.2165823064633871},
#  {'trip_distance': 1.56,
#   'pickup_latitude': 40.68078,
#   'pickup_longitude': -73.967735,
#   'distance_from_selected': 0.1899865424839425},
#  {'trip_distance': 2.9,
#   'pickup_latitude': 40.749994,
#   'pickup_longitude': -73.994031,
#   'distance_from_selected': 0.23736924859173417},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.801351,
#   'pickup_longitude': -73.961519,
#   'distance_from_selected': 0.23870848012167187},
#  {'trip_distance': 2.4,
#   'pickup_latitude': 40.766223,
#   'pickup_longitude': -73.981952,
#   'distance_from_selected': 0.23456104427846333},
#  {'trip_distance': 2.08,
#   'pickup_latitude': 40.740045,
#   'pickup_longitude': -73.982178,
# ...
#   'pickup_latitude': 40.769119,
#   'pickup_longitude': -73.987085,
#   'distance_from_selected': 0.24045214256895173},
#  {'trip_distance': 2.64,
#   'pickup_latitude': 40.750492,
#   'pickup_longitude': -73.99465,
#   'distance_from_selected': 0.23814475010799352},
#  {'trip_distance': 11.3,
#   'pickup_latitude': 40.779416,
#   'pickup_longitude': -73.957448,
#   'distance_from_selected': 0.2217010019824005},
#  {'trip_distance': 1.7,
#   'pickup_latitude': 40.779454,
#   'pickup_longitude': -73.961831,
#   'distance_from_selected': 0.22522475675867176},
#  {'trip_distance': 8.12,
#   'pickup_latitude': 40.773952,
#   'pickup_longitude': -73.871235,
#   'distance_from_selected': 0.15731021794213085},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.756805,
#   'pickup_longitude': -73.990317,
#   'distance_from_selected': 0.23717805150140536},
#  {'trip_distance': 0.2,
#   'pickup_latitude': 40.766251,
#   'pickup_longitude': -73.98011,
#   'distance_from_selected': 0.23300066892822238},
#  {'trip_distance': 4.6,
#   'pickup_latitude': 40.747098,
#   'pickup_longitude': -73.98622,
#   'distance_from_selected': 0.229084588228896},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.774347,
#   'pickup_longitude': -73.963485,
#   'distance_from_selected': 0.2235604743106504},
#  {'trip_distance': 3.05,
#   'pickup_latitude': 40.73735,
#   'pickup_longitude': -73.988662,
#   'distance_from_selected': 0.22713784304691137},
#  {'trip_distance': 1.03,
#   'pickup_latitude': 40.755507,
#   'pickup_longitude': -73.976157,
#   'distance_from_selected': 0.2241466871002154},
#  {'trip_distance': 1.09,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance_from_selected': 84.23581962219279},
#  {'trip_distance': 2.2,
#   'pickup_latitude': 40.77734,
#   'pickup_longitude': -73.978578,
#   'distance_from_selected': 0.23768537541043935},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.730313,
#   'pickup_longitude': -74.00019,
#   'distance_from_selected': 0.2350713422112602},
#  {'trip_distance': 0.78,
#   'pickup_latitude': 40.770965,
#   'pickup_longitude': -73.964002,
#   'distance_from_selected': 0.2220462891583601},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.747897,
#   'pickup_longitude': -74.003746,
#   'distance_from_selected': 0.24523219581654615},
#  {'trip_distance': 3.5,
#   'pickup_latitude': 40.743013,
#   'pickup_longitude': -73.992796,
#   'distance_from_selected': 0.2332435161906978},
#  {'trip_distance': 2.5,
#   'pickup_latitude': 40.757036,
#   'pickup_longitude': -73.976146,
#   'distance_from_selected': 0.22489496688899274},
#  {'trip_distance': 1.27,
#   'pickup_latitude': 40.75083,
#   'pickup_longitude': -73.990808,
#   'distance_from_selected': 0.2348586437923928},
#  {'trip_distance': 0.63,
#   'pickup_latitude': 40.747865,
#   'pickup_longitude': -73.99322,
#   'distance_from_selected': 0.23570521955399765},
#  {'trip_distance': 1.66,
#   'pickup_latitude': 40.758215,
#   'pickup_longitude': -73.937667,
#   'distance_from_selected': 0.19317730693330024},
#  {'trip_distance': 2.38,
#   'pickup_latitude': 40.750687,
#   'pickup_longitude': -73.943522,
#   'distance_from_selected': 0.1937434442581256},
#  {'trip_distance': 1.82,
#   'pickup_latitude': 40.734432,
#   'pickup_longitude': -73.99974,
#   'distance_from_selected': 0.2361809887861475},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.766799,
#   'pickup_longitude': -73.983307,
#   'distance_from_selected': 0.2360188236772644},
#  {'trip_distance': 1.9,
#   'pickup_latitude': 40.752133,
#   'pickup_longitude': -74.004754,
#   'distance_from_selected': 0.24794832377937964},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.719627,
#   'pickup_longitude': -74.00689,
#   'distance_from_selected': 0.23775876296995077},
#  {'trip_distance': 12.55,
#   'pickup_latitude': 40.77012,
#   'pickup_longitude': -73.86361,
#   'distance_from_selected': 0.14985716032275284},
#  {'trip_distance': 0.3,
#   'pickup_latitude': 40.753714,
#   'pickup_longitude': -73.992042,
#   'distance_from_selected': 0.23726850579038294},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.779378,
#   'pickup_longitude': -73.97747,
#   'distance_from_selected': 0.2379110694019939},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.764967,
#   'pickup_longitude': -73.989047,
#   'distance_from_selected': 0.24003258765842772},
#  {'trip_distance': 3.9,
#   'pickup_latitude': 40.724772,
#   'pickup_longitude': -73.990509,
#   'distance_from_selected': 0.22404543825974874},
#  {'trip_distance': 2.18,
#   'pickup_latitude': 40.734817,
#   'pickup_longitude': -73.990455,
#   'distance_from_selected': 0.2277662682532252},
#  {'trip_distance': 0.3,
#   'pickup_latitude': 40.751752,
#   'pickup_longitude': -73.990012,
#   'distance_from_selected': 0.23456653573772876},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.756564,
#   'pickup_longitude': -73.994046,
#   'distance_from_selected': 0.2403611122706826},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.742736,
#   'pickup_longitude': -74.000354,
#   'distance_from_selected': 0.2400097375774622},
#  {'trip_distance': 9.7,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance_from_selected': 84.23581962219279},
#  {'trip_distance': 1.28,
#   'pickup_latitude': 40.741672,
#   'pickup_longitude': -74.004627,
#   'distance_from_selected': 0.2434941039388868},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.72597,
#   'pickup_longitude': -73.99738,
#   'distance_from_selected': 0.23089645579783993},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.743772,
#   'pickup_longitude': -73.992388,
#   'distance_from_selected': 0.2331938596275718},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.71032,
#   'pickup_longitude': -74.009677,
#   'distance_from_selected': 0.23768171706927788},
#  {'trip_distance': 3.2,
#   'pickup_latitude': 40.710885,
#   'pickup_longitude': -74.010269,
#   'distance_from_selected': 0.23840651666009133},
#  {'trip_distance': 1.46,
#   'pickup_latitude': 40.768567,
#   'pickup_longitude': -73.969685,
#   'distance_from_selected': 0.22542564440187363},
#  {'trip_distance': 4.19,
#   'pickup_latitude': 40.755322,
#   'pickup_longitude': -73.987748,
#   'distance_from_selected': 0.23421332974021733},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.750872,
#   'pickup_longitude': -73.993015,
#   'distance_from_selected': 0.23684969104687797},
#  {'trip_distance': 5.8,
#   'pickup_latitude': 40.691887,
#   'pickup_longitude': -73.982322,
#   'distance_from_selected': 0.20656597540011276},
#  {'trip_distance': 1.33,
#   'pickup_latitude': 40.753002,
#   'pickup_longitude': -73.996735,
#   'distance_from_selected': 0.2411296007731161},
#  {'trip_distance': 0.34,
#   'pickup_latitude': 40.765657,
#   'pickup_longitude': -73.970445,
#   'distance_from_selected': 0.2244841239687116},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.718429,
#   'pickup_longitude': -73.987265,
#   'distance_from_selected': 0.21880740377327},
#  {'trip_distance': 0.55,
#   'pickup_latitude': 40.75261,
#   'pickup_longitude': -73.978503,
#   'distance_from_selected': 0.22478939256335487},
#  {'trip_distance': 0.4,
#   'pickup_latitude': 40.774841,
#   'pickup_longitude': -73.963199,
#   'distance_from_selected': 0.2236137755193156},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.820267,
#   'pickup_longitude': -73.955068,
#   'distance_from_selected': 0.24692002238174326},
#  {'trip_distance': 1.98,
#   'pickup_latitude': 40.749905,
#   'pickup_longitude': -73.995245,
#   'distance_from_selected': 0.23841943345709007},
#  {'trip_distance': 1.55,
#   'pickup_latitude': 40.790222,
#   'pickup_longitude': -73.976825,
#   'distance_from_selected': 0.24368225099297514},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.751243,
#   'pickup_longitude': -73.993928,
#   'distance_from_selected': 0.2378322461168808},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.769372,
#   'pickup_longitude': -73.984837,
#   'distance_from_selected': 0.23866142523038816},
#  {'trip_distance': 2.9,
#   'pickup_latitude': 40.802452,
#   'pickup_longitude': -73.9623,
#   'distance_from_selected': 0.24002000738272136},
#  {'trip_distance': 1.13,
#   'pickup_latitude': 40.740012,
#   'pickup_longitude': -73.99121,
#   'distance_from_selected': 0.23055234564844365},
#  {'trip_distance': 1.79,
#   'pickup_latitude': 40.724477,
#   'pickup_longitude': -73.98706,
#   'distance_from_selected': 0.2207195307828495},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.649679,
#   'pickup_longitude': -73.804526,
#   'distance_from_selected': 0.02384164627285503},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.763434,
#   'pickup_longitude': -73.965213,
#   'distance_from_selected': 0.21887934828348357},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.813836,
#   'pickup_longitude': -73.936919,
#   'distance_from_selected': 0.2297236450107013},
#  {'trip_distance': 4.4,
#   'pickup_latitude': 40.748613,
#   'pickup_longitude': -73.983003,
#   'distance_from_selected': 0.22689724488851712},
#  {'trip_distance': 1.51,
#   'pickup_latitude': 40.756067,
#   'pickup_longitude': -73.990297,
#   'distance_from_selected': 0.23681336013409593},
#  {'trip_distance': 0.96,
#   'pickup_latitude': 40.751127,
#   'pickup_longitude': -73.993905,
#   'distance_from_selected': 0.23775986371547217},
#  {'trip_distance': 10.9,
#   'pickup_latitude': 40.757541,
#   'pickup_longitude': -73.974641,
#   'distance_from_selected': 0.22384480043548957},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.783417,
#   'pickup_longitude': -73.951313,
#   'distance_from_selected': 0.2193569713913848},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.755617,
#   'pickup_longitude': -73.962448,
#   'distance_from_selected': 0.2123847874330917},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.770837,
#   'pickup_longitude': -73.991015,
#   'distance_from_selected': 0.24470550797643137},
#  {'trip_distance': 2.55,
#   'pickup_latitude': 40.770932,
#   'pickup_longitude': -73.86622,
#   'distance_from_selected': 0.15198122339289416},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.742625,
#   'pickup_longitude': -73.995955,
#   'distance_from_selected': 0.23595292168142074},
#  {'trip_distance': 4.9,
#   'pickup_latitude': 40.767386,
#   'pickup_longitude': -73.98615,
#   'distance_from_selected': 0.23875883400619918},
#  {'trip_distance': 1.62,
#   'pickup_latitude': 40.729417,
#   'pickup_longitude': -73.98997,
#   'distance_from_selected': 0.22524144984660543},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance_from_selected': 84.23581962219279},
#  {'trip_distance': 3.38,
#   'pickup_latitude': 40.76026,
#   'pickup_longitude': -73.97671,
#   'distance_from_selected': 0.22700415524831416},
#  {'trip_distance': 1.6,
#   'pickup_latitude': 40.748453,
#   'pickup_longitude': -73.973209,
#   'distance_from_selected': 0.21815419283158352},
#  {'trip_distance': 6.5,
#   'pickup_latitude': 40.763605,
#   'pickup_longitude': -73.98895,
#   'distance_from_selected': 0.2392704708588214},
#  {'trip_distance': 0.81,
#   'pickup_latitude': 40.735872,
#   'pickup_longitude': -74.006705,
#   'distance_from_selected': 0.24317605957207233},
#  {'trip_distance': 0.25,
#   'pickup_latitude': 40.761363,
#   'pickup_longitude': -73.969672,
#   'distance_from_selected': 0.22154733041272012},
#  {'trip_distance': 2.86,
#   'pickup_latitude': 40.661145,
#   'pickup_longitude': -73.997122,
#   'distance_from_selected': 0.21657536519420512},
#  {'trip_distance': 1.05,
#   'pickup_latitude': 40.748542,
#   'pickup_longitude': -73.987952,
#   'distance_from_selected': 0.23127923362897151},
#  {'trip_distance': 3.7,
#   'pickup_latitude': 40.781112,
#   'pickup_longitude': -73.954135,
#   'distance_from_selected': 0.2201204422787649},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.762465,
#   'pickup_longitude': -73.957122,
#   'distance_from_selected': 0.21158100200396132},
#  {'trip_distance': 2.27,
#   'pickup_latitude': 40.74805,
#   'pickup_longitude': -74.00412,
#   'distance_from_selected': 0.24563587787617974},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.780242,
#   'pickup_longitude': -73.959577,
#   'distance_from_selected': 0.2238957298230586},
#  {'trip_distance': 3.1,
#   'pickup_latitude': 40.764726,
#   'pickup_longitude': -73.976783,
#   'distance_from_selected': 0.2293664761577007},
#  {'trip_distance': 0.2,
#   'pickup_latitude': 40.733294,
#   'pickup_longitude': -74.002744,
#   'distance_from_selected': 0.23854034722034909},
#  {'trip_distance': 1.08,
#   'pickup_latitude': 40.74976,
#   'pickup_longitude': -73.993847,
#   'distance_from_selected': 0.23710075223204763},
#  {'trip_distance': 1.7,
#   'pickup_latitude': 40.753168,
#   'pickup_longitude': -73.969728,
#   'distance_from_selected': 0.21740317791606237},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.764099,
#   'pickup_longitude': -73.973033,
#   'distance_from_selected': 0.22584516724960493},
#  {'trip_distance': 6.8,
#   'pickup_latitude': 40.796757,
#   'pickup_longitude': -73.970537,
#   'distance_from_selected': 0.242694577726818},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.765015,
#   'pickup_longitude': -73.976836,
#   'distance_from_selected': 0.22956265206039758},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.722397,
#   'pickup_longitude': -73.988933,
#   'distance_from_selected': 0.22173321523398956},
#  {'trip_distance': 1.48,
#   'pickup_latitude': 40.784722,
#   'pickup_longitude': -73.958018,
#   'distance_from_selected': 0.22540479419923667},
#  {'trip_distance': 2.03,
#   'pickup_latitude': 40.734082,
#   'pickup_longitude': -74.006202,
#   'distance_from_selected': 0.24204501062406236},
#  {'trip_distance': 0.56,
#   'pickup_latitude': 40.74772,
#   'pickup_longitude': -73.98274,
#   'distance_from_selected': 0.22625644963183772},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.774329,
#   'pickup_longitude': -73.988897,
#   'distance_from_selected': 0.24471900810929964},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.742366,
#   'pickup_longitude': -73.99317,
#   'distance_from_selected': 0.23331216379778297},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.739342,
#   'pickup_longitude': -74.001677,
#   'distance_from_selected': 0.2398634145362772},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.756363,
#   'pickup_longitude': -73.985773,
#   'distance_from_selected': 0.2329689190814931},
#  {'trip_distance': 3.8,
#   'pickup_latitude': 40.738254,
#   'pickup_longitude': -73.983499,
#   'distance_from_selected': 0.22280774559471406},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.735046,
#   'pickup_longitude': -73.990119,
#   'distance_from_selected': 0.227548074254659},
#  {'trip_distance': 3.1,
#   'pickup_latitude': 40.755857,
#   'pickup_longitude': -73.997045,
#   'distance_from_selected': 0.2426976363997004},
#  {'trip_distance': 0.88,
#   'pickup_latitude': 40.772357,
#   'pickup_longitude': -73.960927,
#   'distance_from_selected': 0.22032276872352616},
#  {'trip_distance': 1.78,
#   'pickup_latitude': 40.775272,
#   'pickup_longitude': -73.95043,
#   'distance_from_selected': 0.21360973274642817},
#  {'trip_distance': 7.68,
#   'pickup_latitude': 40.763642,
#   'pickup_longitude': -73.988995,
#   'distance_from_selected': 0.2393278945902501},
#  {'trip_distance': 12.15,
#   'pickup_latitude': 40.768787,
#   'pickup_longitude': -73.862845,
#   'distance_from_selected': 0.14832319519886364},
#  {'trip_distance': 0.83,
#   'pickup_latitude': 40.772327,
#   'pickup_longitude': -73.952635,
#   'distance_from_selected': 0.21359264218132767},
#  {'trip_distance': 1.6,
#   'pickup_latitude': 40.750617,
#   'pickup_longitude': -73.97391,
#   'distance_from_selected': 0.2198032773390841},
#  {'trip_distance': 4.2,
#   'pickup_latitude': 40.74049,
#   'pickup_longitude': -73.998152,
#   'distance_from_selected': 0.23708673097413882},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.759067,
#   'pickup_longitude': -73.977369,
#   'distance_from_selected': 0.22697016960384928},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.762444,
#   'pickup_longitude': -73.98244,
#   'distance_from_selected': 0.23305172433603788},
#  {'trip_distance': 9.25,
#   'pickup_latitude': 40.774087,
#   'pickup_longitude': -73.874592,
#   'distance_from_selected': 0.1593657515685297},
#  {'trip_distance': 0.4,
#   'pickup_latitude': 40.781736,
#   'pickup_longitude': -73.981283,
#   'distance_from_selected': 0.2423895340253037},
#  {'trip_distance': 1.46,
#   'pickup_latitude': 40.757812,
#   'pickup_longitude': -73.989042,
#   'distance_from_selected': 0.23653305762197543},
#  {'trip_distance': 0.53,
#   'pickup_latitude': 40.787172,
#   'pickup_longitude': -73.97763,
#   'distance_from_selected': 0.2425285787778478}]

# %% [markdown]
# Now write the nearest neighbors formula to calculate the distance of the `selected_trip` from all of the `cleaned_trips` in our dataset.  If no number is provided, it should return the top 3 neighbors.

# %%
def nearest_neighbors(selected_trip, trips, number = 3):
    #sort distance from selected, return sorted by top 3
    number = number or 3
    each_neighbors_distance
    sorted_trips = sorted(selected_trip, 
    pass
#https://github.com/learn-co-students/applying-nearest-neighbors-data-science-intro-000
                          
    neighbor_distances = distance_all(selected_individual, neighbors)
    sorted_neighbors = sorted(neighbor_distances, key=lambda neighbor: neighbor['distance'])
    return sorted_neighbors[:number]

# %%
new_trip = {'pickup_latitude': 40.64499,
'pickup_longitude': -73.78115,
'trip_distance': 18.38}

nearest_three_neighbors = nearest_neighbors(new_trip, cleaned_trips or [], number = 3)
nearest_three_neighbors
# [{'distance_from_selected': 0.0004569288784918792,
#   'pickup_latitude': 40.64483,
#   'pickup_longitude': -73.781578,
#   'trip_distance': 7.78},
#  {'distance_from_selected': 0.0011292165425673159,
#   'pickup_latitude': 40.644657,
#   'pickup_longitude': -73.782229,
#   'trip_distance': 12.7},
#  {'distance_from_selected': 0.0042359798158141185,
#   'pickup_latitude': 40.648509,
#   'pickup_longitude': -73.783508,
#   'trip_distance': 17.3}]

# %% [markdown]
# Ok great! Now that we can provide a new trip location, and find the distances of the three nearest trips, we can take  calculate an estimate of the trip distance for that new trip location.
#
# We do so simply by calculating the average of it's nearest neighbors.

# %%
import statistics
def mean_distance(neighbors):
    nearest_distances = list(map(lambda neighbor: neighbor['trip_distance'], neighbors))
    return round(statistics.mean(nearest_distances), 3)

nearest_three_neighbors = nearest_neighbors(new_trip, cleaned_trips or [], number = 3)
distance_estimate_of_selected_trip = mean_distance(nearest_three_neighbors) # 12.593
distance_estimate_of_selected_trip

# %% [markdown]
# ### Choosing the correct number of neighbors

# %% [markdown]
# Now, as we know from the last lesson, one tricky element is to determine how many neighbors to choose, our $k$ value,  before calculating the average.  We want to choose our value of $k$ such that it properly matches actual data, and so that it applies to new data.  There are fancy formulas to ensure that we **train** our algorithm so that our formula is optimized for all data, but here let's see different $k$ values manually.  This is the gist of choosing our $k$ value:
#
# * If we choose a $k$ value too low, our formula will be too heavily influenced by a single neighbor, whereas if our $k$ value is too high, we will be choosing so many neighbors that our nearest neighbors formula will not be adjust enough according to locations.
#
# Ok, let's experiment with this.

# %% [markdown]
# First, let's choose a midtown location, to see what the trip distance would be.  A Google search reveals the coordinates of 51st and 7th avenue to be the following.

# %%
midtown_trip = dict(pickup_latitude=40.761710, pickup_longitude=-73.982760)

# %%
seven_closest = nearest_neighbors(midtown_trip, cleaned_trips, number = 7)
seven_closest
# [{'trip_distance': 0.58,
#   'pickup_latitude': 40.761372,
#   'pickup_longitude': -73.982602,
#   'distance_from_selected': 0.00037310588309379025},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.762444,
#   'pickup_longitude': -73.98244,
#   'distance_from_selected': 0.00080072217404248},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.762767,
#   'pickup_longitude': -73.982293,
#   'distance_from_selected': 0.0011555682584735844},
#  {'trip_distance': 8.3,
#   'pickup_latitude': 40.762868,
#   'pickup_longitude': -73.983233,
#   'distance_from_selected': 0.0012508768924205918},
#  {'trip_distance': 1.26,
#   'pickup_latitude': 40.760057,
#   'pickup_longitude': -73.983502,
#   'distance_from_selected': 0.0018118976240381972},
#  {'trip_distance': 0.0,
#   'pickup_latitude': 40.760644,
#   'pickup_longitude': -73.984531,
#   'distance_from_selected': 0.002067074502774709},
#  {'trip_distance': 1.72,
#   'pickup_latitude': 40.762107,
#   'pickup_longitude': -73.98479,
#   'distance_from_selected': 0.0020684557041472677}]

# %% [markdown]
# Looking at the `distance_from_selected` it appears that our our trips are still fairly close to our selected trip.  Notice that most of the data is within a distance of .002 away, so going to the top 7 nearest neighbors didn't seem to give us neighbors too far from each other, which is a good sign.
#
# Still, it's hard to know what distance in latitude and longitude really look like, so let's map the data.

# %%
midtown_location = location(midtown_trip) # [40.76171, -73.98276]
midtown_map = map_from(midtown_location, 16)
closest_markers = markers_from_trips(seven_closest)

add_markers(closest_markers, midtown_map)

# %% [markdown]
# Ok.  These locations stay fairly close to our estimated location of 51st street and 7th Avenue.  So they could be a good estimate of a trip distance.

# %%
mean_distance(seven_closest) # 2.009

# %% [markdown]
# Ok, now let's try a different location

# %%
charging_bull_closest = nearest_neighbors({'pickup_latitude': 40.7049, 'pickup_longitude': -74.0137}, cleaned_trips, number = 12)

# %%
mean_distance(charging_bull_closest) # 3.145

# %% [markdown]
# Ok, so there appears to be a significant difference between choosing a location near Times Square versus choosing a location at Wall Street.

# %% [markdown]
# ### Summary

# %% [markdown]
# In this lab, we used the nearest neighbors function to predict the length of a taxi ride.  To do so, we selected a location, then found a number of taxi rides closest to that location, and finally took the average trip lengths of the nearest taxi rides to find an estimate of the new ride's trip length.  You can see that even with just a little bit of math and programming we can begin to make meaningful predictions with data.
